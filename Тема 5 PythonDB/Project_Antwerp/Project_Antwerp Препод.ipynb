# %% [markdown]
# <img src=../../Img/sci.png>
#
# ### Финансовый университет
#
# ##  Инструментальная поддержка анализа финансово-экономических данных
#
# # Тема 5. Работа с базами данных в Пайтон. Библиотека SQLAlchemy Core
#
# Семинар<br>
# 10 апреля 2021 года<br>
# 24 апреля 2021 года <br>
# Поток: ПМ18-1, ПМ18-2, ПМ18-3, ПМ18-4
#
# Преподаватель: Смирнов Михаил Викторович, доцент Департамента анализа данных и машинного обучения Финансового университета при Правительстве Российской Федерации. mvsmirnov@fa.ru
#
# Москва - 2021
#
# При подготовке материалов учебных занятий использовались источники
# - Essential SQLAlchemy: Mapping Python to Databases 2nd Edition. Jason Myers, Rick Copeland. O'Reilly Media, Inc. 2015.
# - <a href="http://insideairbnb.com/get-the-data.html">Inside Airbnb</a>
#
# # Проект Антверпен
#
# <img src="./Img/Antwerp_1.png">
#
# ## Задание
# Используя исходные данные системы <a href="http://insideairbnb.com/get-the-data.html">*Airbnb*</a> в формате *csv* об объектах размещения туристов в Антверпене, создать структуру реляционной базы данных согласно схеме. Создать первичные и внешние ключи, а также другие необходимые ограничения. Наполнить базу данных сведениями об объектах размещения в Антверпене.
#
# <img src=./Img/Schema.png>

# %% [markdown]
# # 1. Изучение источника данных

# %%
import pandas as pd

# %%
df=pd.read_csv("Data/listings_antwerp.csv")
df
# Out:
#             id                                               name    host_id  \
# 0        50904      aplace/antwerp: cosy suite - fashion district     234077
# 1        67776                 Beautiful Big House Center Antwerp     334804
# 2       116134                  Trendy Vacation Apartment Antwerp     586942
# 3       224333         Large stylish room in 1930s house + garden    1167377
# 4       224682              APARTMENT ROSCAM - OLD CENTRE ANTWERP    1263933
# ...        ...                                                ...        ...
# 1711  48217347    Antwerp top location! Beautiful 1 BDR apartment  129071533
# 1712  48224026  New LUXE DESIGN apt in centre Het zuid with HO...  389076822
# 1713  48227279  Recently renovated, light apartment at great spot   70627813
# 1714  48261827                   Design appartement op toplocatie  266540939
# 1715  48278438             Gerenoveerd appartement op trendy zuid   70922398
#
#                       host_name  neighbourhood_group          neighbourhood  \
# 0                         Karin                  NaN     Historisch Centrum
# 1                           Ann                  NaN           Sint-Andries
# 2                          Paul                  NaN               Eilandje
# 3                         Geert                  NaN       Deurne Zuid West
# 4                      Kristien                  NaN           Sint-Andries
# ...                         ...                  ...                    ...
# 1711                      Funny                  NaN               Eilandje
# 1712  Jean-Paul From BnbSupport                  NaN                   Zuid
# 1713                       Enid                  NaN  Nieuw - Kwartier Oost
# 1714                      Katia                  NaN      Theaterbuurt-Meir
# 1715                        Zoe                  NaN                   Zuid
#
#       latitude  longitude        room_type  price  minimum_nights  \
# 0     51.21825    4.39901       Hotel room    145               1
# 1     51.21467    4.39225  Entire home/apt     50               7
# 2     51.23051    4.40593  Entire home/apt    150               2
# 3     51.19772    4.45853     Private room     16              14
# 4     51.21722    4.39790  Entire home/apt     70               2
# ...        ...        ...              ...    ...             ...
# 1711  51.22729    4.40859  Entire home/apt     80               7
# 1712  51.21135    4.39703  Entire home/apt    399               2
# 1713  51.18437    4.43935  Entire home/apt     45              30
# 1714  51.21321    4.40922  Entire home/apt    145               7
# 1715  51.21033    4.39729  Entire home/apt     80               1
#
#       number_of_reviews last_review  reviews_per_month  \
# 0                     1  2015-05-06               0.01
# 1                     9  2016-10-24               0.08
# 2                   102  2020-11-16               0.93
# 3                     2  2020-07-04               0.02
# 4                   344  2021-01-28               3.13
# ...                 ...         ...                ...
# 1711                  0         NaN                NaN
# 1712                  0         NaN                NaN
# 1713                  0         NaN                NaN
# 1714                  0         NaN                NaN
# 1715                  0         NaN                NaN
#
#       calculated_host_listings_count  availability_365
# 0                                  4               226
# 1                                  2               210
# 2                                  1               351
# 3                                  2               310
# 4                                  1               299
# ...                              ...               ...
# 1711                               1                90
# 1712                               1               364
# 1713                               1               245
# 1714                               1                87
# 1715                               1                19
#
# [1716 rows x 16 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1716 entries, 0 to 1715
# Data columns (total 16 columns):
#  #   Column                          Non-Null Count  Dtype
# ---  ------                          --------------  -----
#  0   id                              1716 non-null   int64
#  1   name                            1716 non-null   object
#  2   host_id                         1716 non-null   int64
#  3   host_name                       1716 non-null   object
#  4   neighbourhood_group             0 non-null      float64
#  5   neighbourhood                   1716 non-null   object
#  6   latitude                        1716 non-null   float64
#  7   longitude                       1716 non-null   float64
#  8   room_type                       1716 non-null   object
#  9   price                           1716 non-null   int64
#  10  minimum_nights                  1716 non-null   int64
#  11  number_of_reviews               1716 non-null   int64
#  12  last_review                     1405 non-null   object
#  13  reviews_per_month               1405 non-null   float64
#  14  calculated_host_listings_count  1716 non-null   int64
#  15  availability_365                1716 non-null   int64
# dtypes: float64(4), int64(7), object(5)
# memory usage: 214.6+ KB

# %% [markdown]
# Удалим столбец *neighbourhood_group*, так как он не содержит данных

# %%
df.drop("neighbourhood_group", axis=1, inplace=True)

# %% [markdown]
# В поле *last_review* более 300 записей содержат пустые значения. Заменим все такие значения на дату 1 января 1990 года

# %%
df["last_review"].fillna("1990-01-01", inplace=True)

# %% [markdown]
# Также имеются пустые значения в поле *number_of_reviews*. Такие заменим на нуль.

# %%
df["reviews_per_month"].fillna(0, inplace=True)

# %% [markdown]
# # 2. Создание базы данных *Antwerp.db*

# %%
# ! pip install sqlalchemy

# %%
import sqlalchemy

from sqlalchemy import (create_engine, MetaData, Table, Column,
                        Integer, Numeric, String, DateTime, Date, Boolean,
                        ForeignKey, PrimaryKeyConstraint, UniqueConstraint, 
                        CheckConstraint, ForeignKeyConstraint,
                        insert, select, func)

from datetime import date, datetime as dt
from pprint import pprint

engine = create_engine('sqlite:///Antwerp.db')
metadata = MetaData()

# %%
listings = Table('listings', metadata,
            Column('listing_id',Integer(),primary_key=True),
            Column('listing_name',String(100),index=True),
            Column('host_id',Integer()),
            Column('neighbourhood_id',Integer()),
            Column('latitude',Numeric(10,2)),
            Column('longitude',Numeric(10,2)),
            Column('room_type_id',Integer()),
            Column('price',Integer()),
            Column('minimum_nights',Integer()),
            Column('number_of_reviews', Integer()),
            Column('last_review', DateTime()),
            Column('reviews_per_month', Numeric(10,2)),
            Column('availability_365', Integer()),
            ForeignKeyConstraint(['host_id'], ['hosts.host_id']),
            ForeignKeyConstraint(['neighbourhood_id'], ['neighbourhoods.neigh_id']),
            ForeignKeyConstraint(['room_type_id'], ['room_types.room_type_id']),
            extend_existing=True
            )

# %%
users = Table('users',metadata,
            Column('user_id',Integer(),primary_key=True),
            Column('user_name',String(15),nullable=False,unique=True),
            Column('email_address',String(255),nullable=False),
            Column('phone',String(20),nullable=False),
            Column('password',String(25),nullable=False),
            Column('created_on',Date(),default=date.today()),
            Column('updated_on',Date(),default=date.today(),onupdate=date.today()),
            extend_existing=True
           )

# %%
orders = Table('orders', metadata,
            Column('order_id', Integer(),primary_key=True),
            Column('user_id', ForeignKey('users.user_id')),
            extend_existing=True
            )

# %%
line_items = Table('line_items', metadata,
                   Column('line_item_id', Integer(), primary_key=True),
                   Column('order_id', Integer()),
                   Column('listing_id', ForeignKey('listings.listing_id')),
                   Column('item_start_date', Date()),
                   Column('item_end_date', Date()),
                   Column('item_price', Integer()),
                   extend_existing=True
                  )

line_items.append_constraint(
    ForeignKeyConstraint(['order_id'], ['orders.order_id'])
)

# %%
neighbourhoods = Table('neighbourhoods',metadata,
                    Column('neigh_id',Integer(),primary_key=True),
                    Column('neigh_name',String(30)),
                    extend_existing=True
                   )

# %%
hosts = Table('hosts',metadata,
           Column('host_id',Integer(),primary_key=True),
           Column('host_name',String(30))
          )

# %%
room_types = Table('room_types',metadata,
                Column('room_type_id',Integer(),primary_key=True),
                Column('room_type_name',String(30))
               )

# %%
metadata.create_all(engine)

# %% [markdown]
# Проверим, какие таблицы созданы

# %%
metadata.tables.keys()
# Out:
# dict_keys(['listings', 'users', 'orders', 'line_items', 'neighbourhoods', 'hosts', 'room_types'])

# %%
pprint(metadata.tables)
# Out:
# {'hosts': Table('hosts', MetaData(bind=None), Column('host_id', Integer(), table=<hosts>, primary_key=True, nullable=False), Column('host_name', String(length=30), table=<hosts>), schema=None),
#  'line_items': Table('line_items', MetaData(bind=None), Column('line_item_id', Integer(), table=<line_items>, primary_key=True, nullable=False), Column('order_id', Integer(), ForeignKey('orders.order_id'), table=<line_items>), Column('listing_id', Integer(), ForeignKey('listings.listing_id'), table=<line_items>), Column('item_start_date', Date(), table=<line_items>), Column('item_end_date', Date(), table=<line_items>), Column('item_price', Integer(), table=<line_items>), schema=None),
#  'listings': Table('listings', MetaData(bind=None), Column('listing_id', Integer(), table=<listings>, primary_key=True, nullable=False), Column('listing_name', String(length=100), table=<listings>), Column('host_id', Integer(), ForeignKey('hosts.host_id'), table=<listings>), Column('neighbourhood_id', Integer(), ForeignKey('neighbourhoods.neigh_id'), table=<listings>), Column('latitude', Numeric(precision=10, scale=2), table=<listings>), Column('longitude', Numeric(precision=10, scale=2), table=<listings>), Column('room_type_id', Integer(), ForeignKey('room_types.room_type_id'), table=<listings>), Column('price', Integer(), table=<listings>), Column('minimum_nights', Integer(), table=<listings>), Column('number_of_reviews', Integer(), table=<listings>), Column('last_review', DateTime(), table=<listings>), Column('reviews_per_month', Numeric(precision=10, scale=2), table=<listings>), Column('availability_365', Integer(), table=<listings>), schema=None),
#  'neighbourhoods': Table('neighbourhoods', MetaData(bind=None), Column('neigh_id', Integer(), table=<neighbourhoods>, primary_key=True, nullable=False), Column('neigh_name', String(length=30), table=<neighbourhoods>), schema=None),
#  'orders': Table('orders', MetaData(bind=None), Column('order_id', Integer(), table=<orders>, primary_key=True, nullable=False), Column('user_id', Integer(), ForeignKey('users.user_id'), table=<orders>), schema=None),
#  'room_types': Table('room_types', MetaData(bind=None), Column('room_type_id', Integer(), table=<room_types>, primary_key=True, nullable=False), Column('room_type_name', String(length=30), table=<room_types>), schema=None),
#  'users': Table('users', MetaData(bind=None), Column('user_id', Integer(), table=<users>, primary_key=True, nullable=False), Column('user_name', String(length=15), table=<users>, nullable=False), Column('email_address', String(length=255), table=<users>, nullable=False), Column('phone', String(length=20), table=<users>, nullable=False), Column('password', String(length=25), table=<users>, nullable=False), Column('created_on', Date(), table=<users>, default=ColumnDefault(datetime.date(2021, 4, 24))), Column('updated_on', Date(), table=<users>, onupdate=ColumnDefault(datetime.date(2021, 4, 24)), default=ColumnDefault(datetime.date(2021, 4, 24))), schema=None)}

# %% [markdown]
# # 3. Наполнение справочников

# %% [markdown]
# Соединение

# %%
connection = engine.connect()

# %% [markdown]
# ## 3.1. Справочник районов

# %%
df.head(1)
# Out:
#       id                                           name  host_id host_name  \
# 0  50904  aplace/antwerp: cosy suite - fashion district   234077     Karin
#
#         neighbourhood  latitude  longitude   room_type  price  minimum_nights  \
# 0  Historisch Centrum  51.21825    4.39901  Hotel room    145               1
#
#    number_of_reviews last_review  reviews_per_month  \
# 0                  1  2015-05-06               0.01
#
#    calculated_host_listings_count  availability_365
# 0                               4               226

# %%
neigh_names = df["neighbourhood"].sort_values().unique()
neigh_list = []
for i, x in enumerate(neigh_names):
    neigh_dict = {'neigh_id':i+1, 'neigh_name':x}
    neigh_list.append(neigh_dict)
pprint(neigh_list[:2])
print("Всего районов:", len(neigh_list))
# Out:
# [{'neigh_id': 1, 'neigh_name': 'Amandus - Atheneum'},
#  {'neigh_id': 2, 'neigh_name': 'Borgerhout Extra Muros'}]
# Всего районов: 53

# %%
ins = neighbourhoods.insert()
connection.execute(ins, neigh_list)

# %% [markdown]
# Проверка - запрос к таблице.

# %%
sel=select([neighbourhoods])
connection.execute(sel).fetchone()
# Out:
# (1, 'Amandus - Atheneum')

# %% [markdown]
# ## 3.2. Справочник типов комнат

# %%
room_type_names=df["room_type"].sort_values().unique()
rooms_list=[]
for i, name in enumerate(room_type_names):
    tmp_dict={"room_type_id":i+1, "room_type_name":name}
    rooms_list.append(tmp_dict)
print(rooms_list[:1])
print("Всего типов комнат:", len(rooms_list))
# Out:
# [{'room_type_id': 1, 'room_type_name': 'Entire home/apt'}]
# Всего типов комнат: 4

# %%
ins=room_types.insert()
connection.execute(ins, rooms_list)

# %% [markdown]
# Проверка - запрос к таблице *room_types*

# %%
sel=select([room_types])
connection.execute(sel).fetchone()
# Out:
# (1, 'Entire home/apt')

# %% [markdown]
# ## 3.3. Справочник владельцев
#
# ### Задание 3.3.1.
# Создайте справочник владельцев недвижимости, сохранив их идентификаторы из набора данных *Антверпен*.

# %%
# Ваш код здесь

# %% [markdown]
# # 4. Наполнение таблиц
#
# ## 4.1.  Таблица *listings*
#
# В процессе наполнения таблицы *listings* мы будем подставлять вместо названий районов, названий типов комнат и имен владельцев их идентификаторы. Для этого испоьзуем ранее созданные справочники районов, типов комнат и владельцев, откуда будем подставлять в таблицу соовтетствующие значения идентификаторов.
#
# **Пример.** Пусть у нас имеется справочник типов комнат - таблица *room_types*. Посмотрим, какие она содержит записи.

# %%
sel = select([room_types])
result = connection.execute(sel).fetchall()
pprint(result)
# Out:
# [(1, 'Entire home/apt'),
#  (2, 'Hotel room'),
#  (3, 'Private room'),
#  (4, 'Shared room')]

# %% [markdown]
# Теперь посмотрим, какой тип комнаты у первой записи таблицы набора данных "Антверпен".

# %%
df.loc[0, 'room_type']
# Out:
# 'Hotel room'

# %% [markdown]
# Это `'Hotel room'`. Чтобы получить идентификатор этого типа комнаты выполним запрос:

# %%
sel = select([room_types.c.room_type_id])
sel = sel.where(room_types.c.room_type_name == df.loc[0, 'room_type'])
result = connection.execute(sel).fetchone()
print(result)
# Out:
# (2,)

# %% [markdown]
# Чтобы узнать, как выглядит запрос, отправляемый в базу данных, можно выполнить команду

# %%
print(str(sel))
print(sel.compile().params)
# Out:
# SELECT room_types.room_type_id
# FROM room_types
# WHERE room_types.room_type_name = :room_type_name_1
# {'room_type_name_1': 'Hotel room'}

# %%
lst = []
for row_id in df.index[:]:
    
    # Определим значение идентификатора района
    sel = select([neighbourhoods.c.neigh_id])
    sel = sel.where(neighbourhoods.c.neigh_name==df.loc[row_id, 'neighbourhood'])
    current_neigh_id = connection.execute(sel).fetchone()[0]
    
    # Определим значение идентификатора типа комнаты
    sel = select([room_types.c.room_type_id])
    sel = sel.where(room_types.c.room_type_name==df.loc[row_id, 'room_type'])
    current_room_type_id = connection.execute(sel).fetchone()[0]
    
    # Значение идентификатора владельца можно взять напрямую из записи набора данных
    current_host_id = df.loc[row_id, 'host_id']
    
    tmp_dict={
        'listing_id': int(df.loc[row_id, 'id']),
        'listing_name': df.loc[row_id, 'name'],
        'host_id': int(current_host_id),
        'neighbourhood_id': int(current_neigh_id),
        'latitude': float(df.loc[row_id, 'latitude']),
        'longitude': float(df.loc[row_id, 'longitude']),
        'room_type_id': int(current_room_type_id),
        'price': int(df.loc[row_id, 'price']),
        'minimum_nights': int(df.loc[row_id, 'minimum_nights']),
        'number_of_reviews': int(df.loc[row_id, 'number_of_reviews']),
        'last_review': dt.strptime(df.loc[row_id, 'last_review'],'%Y-%m-%d'),
        'reviews_per_month': df.loc[row_id, 'reviews_per_month'],
        'availability_365': df.loc[row_id, 'availability_365']
    }    
    lst.append(tmp_dict)

# %%
lst
# Out:
# [{'listing_id': 50904,
#   'listing_name': 'aplace/antwerp: cosy suite - fashion district',
#   'host_id': 234077,
#   'neighbourhood_id': 19,
#   'latitude': 51.21825,
#   'longitude': 4.39901,
#   'room_type_id': 2,
#   'price': 145,
#   'minimum_nights': 1,
#   'number_of_reviews': 1,
#   'last_review': datetime.datetime(2015, 5, 6, 0, 0),
#   'reviews_per_month': 0.01,
#   'availability_365': 226},
#  {'listing_id': 67776,
#   'listing_name': 'Beautiful Big House Center Antwerp',
#   'host_id': 334804,
#   'neighbourhood_id': 43,
#   'latitude': 51.21467,
#   'longitude': 4.39225,
#   'room_type_id': 1,
#   'price': 50,
#   'minimum_nights': 7,
#   'number_of_reviews': 9,
#   'last_review': datetime.datetime(2016, 10, 24, 0, 0),
#   'reviews_per_month': 0.08,
#   'availability_365': 210},
#  {'listing_id': 116134,
#   'listing_name': 'Trendy Vacation Apartment Antwerp',
#   'host_id': 586942,
#   'neighbourhood_id': 14,
#   'latitude': 51.230509999999995,
#   'longitude': 4.405930000000001,
#   'room_type_id': 1,
#   'price': 150,
#   'minimum_nights': 2,
#   'number_of_reviews': 102,
#   'last_review': datetime.datetime(2020, 11, 16, 0, 0),
#   'reviews_per_month': 0.93,
#   'availability_365': 351},
#  {'listing_id': 224333,
#   'listing_name': 'Large stylish room in 1930s house + garden',
#   'host_id': 1167377,
#   'neighbourhood_id': 12,
#   'latitude': 51.197720000000004,
#   'longitude': 4.4585300000000005,
#   'room_type_id': 3,
#   'price': 16,
#   'minimum_nights': 14,
#   'number_of_reviews': 2,
#   'last_review': datetime.datetime(2020, 7, 4, 0, 0),
#   'reviews_per_month': 0.02,
#   'availability_365': 310},
#  {'listing_id': 224682,
#   'listing_name': 'APARTMENT ROSCAM - OLD CENTRE ANTWERP',
#   'host_id': 1263933,
#   'neighbourhood_id': 43,
#   'latitude': 51.217220000000005,
#   'longitude': 4.3979,
#   'room_type_id': 1,
#   'price': 70,
#   'minimum_nights': 2,
#   'number_of_reviews': 344,
#   'last_review': datetime.datetime(2021, 1, 28, 0, 0),
#   'reviews_per_month': 3.13,
#   'availability_365': 299},
#  {'listing_id': 345959,
#   'listing_name': "Marleen's home in Antwerp city",
#   'host_id': 1754396,
#   'neighbourhood_id': 30,
#   'latitude': 51.19935,
#   'longitude': 4.40154,
#   'room_type_id': 1,
#   'price': 55,
#   'minimum_nights': 2,
#   'number_of_reviews': 55,
#   'last_review': datetime.datetime(2020, 9, 22, 0, 0),
#   'reviews_per_month': 0.51,
#   'availability_365': 321},
#  {'listing_id': 363155,
#   'listing_name': '1-bedroom apartment with court yard',
#   'host_id': 1835458,
#   'neighbourhood_id': 1,
#   'latitude': 51.22119,
#   'longitude': 4.41951,
#   'room_type_id': 1,
#   'price': 50,
#   'minimum_nights': 2,
#   'number_of_reviews': 20,
#   'last_review': datetime.datetime(2020, 11, 6, 0, 0),
#   'reviews_per_month': 0.19,
#   'availability_365': 362},
#  {'listing_id': 366252,
#   'listing_name': 'ROOM IN FAMILY HOME near C. Station',
#   'host_id': 1820186,
#   'neighbourhood_id': 3,
#   'latitude': 51.21601,
#   'longitude': 4.43432,
#   'room_type_id': 3,
#   'price': 35,
#   'minimum_nights': 1,
#   'number_of_reviews': 104,
#   'last_review': datetime.datetime(2019, 9, 15, 0, 0),
#   'reviews_per_month': 0.96,
#   'availability_365': 365},
#  {'listing_id': 445201,
#   'listing_name': 'ROOM in FAMILY HOME near Central Sation',
#   'host_id': 1820186,
#   'neighbourhood_id': 3,
#   'latitude': 51.215790000000005,
#   'longitude': 4.43265,
#   'room_type_id': 3,
#   'price': 18,
#   'minimum_nights': 1,
#   'number_of_reviews': 55,
#   'last_review': datetime.datetime(2020, 9, 10, 0, 0),
#   'reviews_per_month': 0.52,
#   'availability_365': 365},
#  {'listing_id': 522693,
#   'listing_name': 'Ahome Awayfromhome',
#   'host_id': 2562294,
#   'neighbourhood_id': 19,
#   'latitude': 51.220009999999995,
#   'longitude': 4.39813,
#   'room_type_id': 1,
#   'price': 282,
#   'minimum_nights': 2,
#   'number_of_reviews': 2,
#   'last_review': datetime.datetime(2017, 10, 27, 0, 0),
#   'reviews_per_month': 0.03,
#   'availability_365': 365},
#  {'listing_id': 603545,
#   'listing_name': '*Perfect* for a Longer Stay | Trendy | City center',
#   'host_id': 2987880,
#   'neighbourhood_id': 18,
#   'latitude': 51.20753,
#   'longitude': 4.40589,
#   'room_type_id': 1,
#   'price': 150,
#   'minimum_nights': 2,
#   'number_of_reviews': 22,
#   'last_review': datetime.datetime(2020, 9, 13, 0, 0),
#   'reviews_per_month': 0.22,
#   'availability_365': 351},
#  {'listing_id': 636664,
#   'listing_name': 'sunny rooftop apartment, sleeps 2-5',
#   'host_id': 462975,
#   'neighbourhood_id': 4,
#   'latitude': 51.21618,
#   'longitude': 4.43037,
#   'room_type_id': 1,
#   'price': 85,
#   'minimum_nights': 2,
#   'number_of_reviews': 81,
#   'last_review': datetime.datetime(2020, 3, 15, 0, 0),
#   'reviews_per_month': 0.79,
#   'availability_365': 365},
#  {'listing_id': 639013,
#   'listing_name': 'The chill place in Antwerp 1',
#   'host_id': 3189018,
#   'neighbourhood_id': 3,
#   'latitude': 51.21748,
#   'longitude': 4.4456,
#   'room_type_id': 3,
#   'price': 85,
#   'minimum_nights': 2,
#   'number_of_reviews': 34,
#   'last_review': datetime.datetime(2018, 7, 22, 0, 0),
#   'reviews_per_month': 0.33,
#   'availability_365': 364},
#  {'listing_id': 685049,
#   'listing_name': "Stylish decorated  room in 'art nouveau house'",
#   'host_id': 3493319,
#   'neighbourhood_id': 39,
#   'latitude': 51.195890000000006,
#   'longitude': 4.41443,
#   'room_type_id': 3,
#   'price': 65,
#   'minimum_nights': 2,
#   'number_of_reviews': 5,
#   'last_review': datetime.datetime(2020, 2, 24, 0, 0),
#   'reviews_per_month': 0.06,
#   'availability_365': 364},
#  {'listing_id': 723033,
#   'listing_name': 'Spacy family studio in Antwerp City',
#   'host_id': 3734348,
#   'neighbourhood_id': 44,
#   'latitude': 51.20955,
#   'longitude': 4.41481,
#   'room_type_id': 1,
#   'price': 63,
#   'minimum_nights': 2,
#   'number_of_reviews': 237,
#   'last_review': datetime.datetime(2020, 3, 8, 0, 0),
#   'reviews_per_month': 2.34,
#   'availability_365': 116},
#  {'listing_id': 772842,
#   'listing_name': 'Stay in a designers place & donate',
#   'host_id': 4050173,
#   'neighbourhood_id': 28,
#   'latitude': 51.21775,
#   'longitude': 4.38434,
#   'room_type_id': 1,
#   'price': 82,
#   'minimum_nights': 7,
#   'number_of_reviews': 66,
#   'last_review': datetime.datetime(2018, 6, 1, 0, 0),
#   'reviews_per_month': 0.67,
#   'availability_365': 365},
#  {'listing_id': 778043,
#   'listing_name': 'cosy & beautiful apartment Antwerp',
#   'host_id': 1735092,
#   'neighbourhood_id': 44,
#   'latitude': 51.203990000000005,
#   'longitude': 4.41249,
#   'room_type_id': 1,
#   'price': 68,
#   'minimum_nights': 2,
#   'number_of_reviews': 62,
#   'last_review': datetime.datetime(2020, 1, 1, 0, 0),
#   'reviews_per_month': 0.62,
#   'availability_365': 364},
#  {'listing_id': 789555,
#   'listing_name': '+++blancoooJOZEFIEN+++ roofterrace',
#   'host_id': 3185214,
#   'neighbourhood_id': 6,
#   'latitude': 51.2117,
#   'longitude': 4.42665,
#   'room_type_id': 1,
#   'price': 93,
#   'minimum_nights': 2,
#   'number_of_reviews': 48,
#   'last_review': datetime.datetime(2020, 3, 9, 0, 0),
#   'reviews_per_month': 0.48,
#   'availability_365': 326},
#  {'listing_id': 813969,
#   'listing_name': '150 m² loft (terrace & river view)',
#   'host_id': 4277604,
#   'neighbourhood_id': 43,
#   'latitude': 51.21347,
#   'longitude': 4.39125,
#   'room_type_id': 1,
#   'price': 215,
#   'minimum_nights': 1,
#   'number_of_reviews': 63,
#   'last_review': datetime.datetime(2021, 1, 3, 0, 0),
#   'reviews_per_month': 0.91,
#   'availability_365': 291},
#  {'listing_id': 842077,
#   'listing_name': '4 Cosy rooms near Central Station',
#   'host_id': 4396703,
#   'neighbourhood_id': 1,
#   'latitude': 51.2215,
#   'longitude': 4.42606,
#   'room_type_id': 3,
#   'price': 40,
#   'minimum_nights': 1,
#   'number_of_reviews': 401,
#   'last_review': datetime.datetime(2020, 7, 7, 0, 0),
#   'reviews_per_month': 4.03,
#   'availability_365': 353},
#  {'listing_id': 866701,
#   'listing_name': '4 Cosy rooms near Central Station',
#   'host_id': 4396703,
#   'neighbourhood_id': 1,
#   'latitude': 51.2215,
#   'longitude': 4.42606,
#   'room_type_id': 3,
#   'price': 40,
#   'minimum_nights': 1,
#   'number_of_reviews': 284,
#   'last_review': datetime.datetime(2020, 7, 14, 0, 0),
#   'reviews_per_month': 2.88,
#   'availability_365': 353},
#  {'listing_id': 890384,
#   'listing_name': '+++ blancoooHOME +++',
#   'host_id': 3185214,
#   'neighbourhood_id': 6,
#   'latitude': 51.21198,
#   'longitude': 4.4269,
#   'room_type_id': 1,
#   'price': 150,
#   'minimum_nights': 7,
#   'number_of_reviews': 0,
#   'last_review': datetime.datetime(1990, 1, 1, 0, 0),
#   'reviews_per_month': 0.0,
#   'availability_365': 347},
#  {'listing_id': 891355,
#   'listing_name': 'BorzeB&B, sleeping in the heart of Antwerp!',
#   'host_id': 1366391,
#   'neighbourhood_id': 49,
#   'latitude': 51.22043,
#   'longitude': 4.40562,
#   'room_type_id': 3,
#   'price': 85,
#   'minimum_nights': 2,
#   'number_of_reviews': 79,
#   'last_review': datetime.datetime(2020, 2, 3, 0, 0),
#   'reviews_per_month': 0.83,
#   'availability_365': 209},
#  {'listing_id': 891884,
#   'listing_name': 'aplace/antwerp: amazing suite & square view',
#   'host_id': 234077,
#   'neighbourhood_id': 19,
#   'latitude': 51.21825,
#   'longitude': 4.39901,
#   'room_type_id': 2,
#   'price': 147,
#   'minimum_nights': 1,
#   'number_of_reviews': 1,
#   'last_review': datetime.datetime(2019, 10, 20, 0, 0),
#   'reviews_per_month': 0.06,
#   'availability_365': 228},
#  {'listing_id': 891907,
#   'listing_name': 'aplace/antwerp: stunning flat with square view',
#   'host_id': 234077,
#   'neighbourhood_id': 19,
#   'latitude': 51.21825,
#   'longitude': 4.39901,
#   'room_type_id': 1,
#   'price': 176,
#   'minimum_nights': 2,
#   'number_of_reviews': 5,
#   'last_review': datetime.datetime(2020, 2, 9, 0, 0),
#   'reviews_per_month': 0.06,
#   'availability_365': 316},
#  {'listing_id': 959200,
#   'listing_name': 'NEST',
#   'host_id': 4715596,
#   'neighbourhood_id': 3,
#   'latitude': 51.215959999999995,
#   'longitude': 4.43764,
#   'room_type_id': 1,
#   'price': 55,
#   'minimum_nights': 2,
#   'number_of_reviews': 58,
#   'last_review': datetime.datetime(2020, 6, 13, 0, 0),
#   'reviews_per_month': 0.65,
#   'availability_365': 240},
#  {'listing_id': 961296,
#   'listing_name': 'Great Classic House in Antwerp (4-10 persons)',
#   'host_id': 3189018,
#   'neighbourhood_id': 3,
#   'latitude': 51.215309999999995,
#   'longitude': 4.44498,
#   'room_type_id': 1,
#   'price': 317,
#   'minimum_nights': 1,
#   'number_of_reviews': 48,
#   'last_review': datetime.datetime(2020, 1, 29, 0, 0),
#   'reviews_per_month': 0.6,
#   'availability_365': 170},
#  {'listing_id': 991824,
#   'listing_name': 'Colourful Inspiration In Every Room',
#   'host_id': 5446991,
#   'neighbourhood_id': 12,
#   'latitude': 51.20316,
#   'longitude': 4.46015,
#   'room_type_id': 1,
#   'price': 77,
#   'minimum_nights': 1,
#   'number_of_reviews': 230,
#   'last_review': datetime.datetime(2020, 10, 4, 0, 0),
#   'reviews_per_month': 2.41,
#   'availability_365': 361},
#  {'listing_id': 1050693,
#   'listing_name': 'Colourful Inspiration In Every Room',
#   'host_id': 5446991,
#   'neighbourhood_id': 12,
#   'latitude': 51.20316,
#   'longitude': 4.46015,
#   'room_type_id': 1,
#   'price': 77,
#   'minimum_nights': 1,
#   'number_of_reviews': 23,
#   'last_review': datetime.datetime(2020, 9, 23, 0, 0),
#   'reviews_per_month': 0.26,
#   'availability_365': 361},
#  {'listing_id': 1105318,
#   'listing_name': 'Number22Antwerp, cosy duplex',
#   'host_id': 6068286,
#   'neighbourhood_id': 52,
#   'latitude': 51.21024,
#   'longitude': 4.39995,
#   'room_type_id': 1,
#   'price': 75,
#   'minimum_nights': 2,
#   'number_of_reviews': 29,
#   'last_review': datetime.datetime(2020, 1, 1, 0, 0),
#   'reviews_per_month': 0.31,
#   'availability_365': 365},
#  {'listing_id': 1108491,
#   'listing_name': '4 Cosy rooms near Central Station! ~ double room',
#   'host_id': 4396703,
#   'neighbourhood_id': 1,
#   'latitude': 51.2215,
#   'longitude': 4.42606,
#   'room_type_id': 3,
#   'price': 40,
#   'minimum_nights': 1,
#   'number_of_reviews': 216,
#   'last_review': datetime.datetime(2020, 8, 23, 0, 0),
#   'reviews_per_month': 2.27,
#   'availability_365': 353},
#  {'listing_id': 1146375,
#   'listing_name': 'Homey apartment near Antwerpen Centraal Station',
#   'host_id': 1764235,
#   'neighbourhood_id': 3,
#   'latitude': 51.21751,
#   'longitude': 4.4298,
#   'room_type_id': 1,
#   'price': 57,
#   'minimum_nights': 1,
#   'number_of_reviews': 165,
#   'last_review': datetime.datetime(2020, 10, 1, 0, 0),
#   'reviews_per_month': 1.76,
#   'availability_365': 350},
#  {'listing_id': 1172376,
#   'listing_name': 'Number22Antwerp, Cosy & Trendy Flat',
#   'host_id': 6068286,
#   'neighbourhood_id': 52,
#   'latitude': 51.21026,
#   'longitude': 4.4013800000000005,
#   'room_type_id': 1,
#   'price': 109,
#   'minimum_nights': 1,
#   'number_of_reviews': 16,
#   'last_review': datetime.datetime(2020, 10, 23, 0, 0),
#   'reviews_per_month': 0.17,
#   'availability_365': 363},
#  {'listing_id': 1172826,
#   'listing_name': 'Bedroom in large antique house near parks+trams',
#   'host_id': 1167377,
#   'neighbourhood_id': 12,
#   'latitude': 51.19813,
#   'longitude': 4.458069999999999,
#   'room_type_id': 3,
#   'price': 16,
#   'minimum_nights': 7,
#   'number_of_reviews': 3,
#   'last_review': datetime.datetime(2020, 3, 4, 0, 0),
#   'reviews_per_month': 0.15,
#   'availability_365': 365},
#  {'listing_id': 1184623,
#   'listing_name': 'Luxe penthouse',
#   'host_id': 4865806,
#   'neighbourhood_id': 14,
#   'latitude': 51.23133,
#   'longitude': 4.41015,
#   'room_type_id': 1,
#   'price': 170,
#   'minimum_nights': 2,
#   'number_of_reviews': 21,
#   'last_review': datetime.datetime(2020, 7, 14, 0, 0),
#   'reviews_per_month': 0.23,
#   'availability_365': 331},
#  {'listing_id': 1209063,
#   'listing_name': 'Room with a view!',
#   'host_id': 6596883,
#   'neighbourhood_id': 4,
#   'latitude': 51.21053,
#   'longitude': 4.43308,
#   'room_type_id': 1,
#   'price': 77,
#   'minimum_nights': 1,
#   'number_of_reviews': 33,
#   'last_review': datetime.datetime(2020, 3, 14, 0, 0),
#   'reviews_per_month': 0.36,
#   'availability_365': 55},
#  {'listing_id': 1227242,
#   'listing_name': 'Cosy ship Hannus Antwerp Belgium',
#   'host_id': 4193029,
#   'neighbourhood_id': 14,
#   'latitude': 51.22775,
#   'longitude': 4.40388,
#   'room_type_id': 3,
#   'price': 60,
#   'minimum_nights': 1,
#   'number_of_reviews': 4,
#   'last_review': datetime.datetime(2020, 7, 26, 0, 0),
#   'reviews_per_month': 0.32,
#   'availability_365': 349},
#  {'listing_id': 1267516,
#   'listing_name': 'Suites in Antwerp:"Suite Frederik"',
#   'host_id': 5758428,
#   'neighbourhood_id': 53,
#   'latitude': 51.207,
#   'longitude': 4.42702,
#   'room_type_id': 1,
#   'price': 179,
#   'minimum_nights': 1,
#   'number_of_reviews': 3,
#   'last_review': datetime.datetime(2013, 10, 13, 0, 0),
#   'reviews_per_month': 0.03,
#   'availability_365': 365},
#  {'listing_id': 1328770,
#   'listing_name': 'Cosy historic Ship Hannus  Antwerp',
#   'host_id': 4193029,
#   'neighbourhood_id': 14,
#   'latitude': 51.22875,
#   'longitude': 4.40254,
#   'room_type_id': 3,
#   'price': 60,
#   'minimum_nights': 1,
#   'number_of_reviews': 136,
#   'last_review': datetime.datetime(2020, 7, 19, 0, 0),
#   'reviews_per_month': 1.47,
#   'availability_365': 351},
#  {'listing_id': 1405414,
#   'listing_name': 'bright apartment with parkview',
#   'host_id': 4870468,
#   'neighbourhood_id': 44,
#   'latitude': 51.213879999999996,
#   'longitude': 4.41573,
#   'room_type_id': 1,
#   'price': 90,
#   'minimum_nights': 3,
#   'number_of_reviews': 98,
#   'last_review': datetime.datetime(2020, 3, 9, 0, 0),
#   'reviews_per_month': 1.07,
#   'availability_365': 178},
#  {'listing_id': 1427505,
#   'listing_name': 'Trendy apartment near city park !',
#   'host_id': 7672678,
#   'neighbourhood_id': 44,
#   'latitude': 51.21205,
#   'longitude': 4.41315,
#   'room_type_id': 1,
#   'price': 47,
#   'minimum_nights': 10,
#   'number_of_reviews': 41,
#   'last_review': datetime.datetime(2019, 10, 31, 0, 0),
#   'reviews_per_month': 0.44,
#   'availability_365': 357},
#  {'listing_id': 1504952,
#   'listing_name': '"Antwerp B&B"',
#   'host_id': 573329,
#   'neighbourhood_id': 6,
#   'latitude': 51.21692,
#   'longitude': 4.42749,
#   'room_type_id': 3,
#   'price': 100,
#   'minimum_nights': 1,
#   'number_of_reviews': 55,
#   'last_review': datetime.datetime(2020, 9, 9, 0, 0),
#   'reviews_per_month': 0.6,
#   'availability_365': 362},
#  {'listing_id': 1577011,
#   'listing_name': 'New and bright apartment in center',
#   'host_id': 8382721,
#   'neighbourhood_id': 45,
#   'latitude': 51.22105,
#   'longitude': 4.42809,
#   'room_type_id': 1,
#   'price': 65,
#   'minimum_nights': 4,
#   'number_of_reviews': 33,
#   'last_review': datetime.datetime(2019, 11, 1, 0, 0),
#   'reviews_per_month': 0.36,
#   'availability_365': 355},
#  {'listing_id': 1585405,
#   'listing_name': 'Relax and enjoy Antwerp :-)',
#   'host_id': 8446724,
#   'neighbourhood_id': 8,
#   'latitude': 51.22337,
#   'longitude': 4.4692300000000005,
#   'room_type_id': 3,
#   'price': 38,
#   'minimum_nights': 3,
#   'number_of_reviews': 196,
#   'last_review': datetime.datetime(2020, 8, 5, 0, 0),
#   'reviews_per_month': 2.15,
#   'availability_365': 365},
#  {'listing_id': 1666809,
#   'listing_name': 'Duplex apartment/loft close to MAS with parking',
#   'host_id': 4127444,
#   'neighbourhood_id': 19,
#   'latitude': 51.22493,
#   'longitude': 4.40333,
#   'room_type_id': 1,
#   'price': 75,
#   'minimum_nights': 2,
#   'number_of_reviews': 8,
#   'last_review': datetime.datetime(2021, 2, 3, 0, 0),
#   'reviews_per_month': 0.66,
#   'availability_365': 201},
#  {'listing_id': 1708652,
#   'listing_name': 'Suites in Antwerp: "suite Joachim"',
#   'host_id': 5758428,
#   'neighbourhood_id': 53,
#   'latitude': 51.20828,
#   'longitude': 4.42645,
#   'room_type_id': 1,
#   'price': 74,
#   'minimum_nights': 2,
#   'number_of_reviews': 2,
#   'last_review': datetime.datetime(2020, 1, 6, 0, 0),
#   'reviews_per_month': 0.13,
#   'availability_365': 365},
#  {'listing_id': 1808782,
#   'listing_name': 'LOFT 1D  - conceptual loft',
#   'host_id': 9478810,
#   'neighbourhood_id': 43,
#   'latitude': 51.21232,
#   'longitude': 4.39571,
#   'room_type_id': 1,
#   'price': 111,
#   'minimum_nights': 2,
#   'number_of_reviews': 191,
#   'last_review': datetime.datetime(2021, 2, 14, 0, 0),
#   'reviews_per_month': 2.18,
#   'availability_365': 257},
#  {'listing_id': 2059774,
#   'listing_name': 'spacious and comfortable apartment',
#   'host_id': 8689159,
#   'neighbourhood_id': 39,
#   'latitude': 51.197140000000005,
#   'longitude': 4.4172199999999995,
#   'room_type_id': 1,
#   'price': 85,
#   'minimum_nights': 6,
#   'number_of_reviews': 12,
#   'last_review': datetime.datetime(2020, 2, 22, 0, 0),
#   'reviews_per_month': 0.14,
#   'availability_365': 362},
#  {'listing_id': 2069688,
#   'listing_name': 'Authentic centre Antwerp: cozy view',
#   'host_id': 10583986,
#   'neighbourhood_id': 19,
#   'latitude': 51.226420000000005,
#   'longitude': 4.401,
#   'room_type_id': 1,
#   'price': 60,
#   'minimum_nights': 2,
#   'number_of_reviews': 139,
#   'last_review': datetime.datetime(2020, 3, 6, 0, 0),
#   'reviews_per_month': 1.59,
#   'availability_365': 364},
#  {'listing_id': 2086302,
#   'listing_name': 'Cozy apartment in Antwerp-Berchem',
#   'host_id': 4218557,
#   'neighbourhood_id': 16,
#   'latitude': 51.1958,
#   'longitude': 4.4392,
#   'room_type_id': 1,
#   'price': 45,
#   'minimum_nights': 30,
#   'number_of_reviews': 12,
#   'last_review': datetime.datetime(2019, 6, 10, 0, 0),
#   'reviews_per_month': 0.14,
#   'availability_365': 247},
#  {'listing_id': 2133274,
#   'listing_name': 'Middelheim Guest House',
#   'host_id': 10885207,
#   'neighbourhood_id': 38,
#   'latitude': 51.17635,
#   'longitude': 4.42433,
#   'room_type_id': 3,
#   'price': 75,
#   'minimum_nights': 1,
#   'number_of_reviews': 13,
#   'last_review': datetime.datetime(2020, 2, 26, 0, 0),
#   'reviews_per_month': 0.22,
#   'availability_365': 365},
#  {'listing_id': 2194840,
#   'listing_name': 'Fully equiped Appartement',
#   'host_id': 11087865,
#   'neighbourhood_id': 49,
#   'latitude': 51.2234,
#   'longitude': 4.41389,
#   'room_type_id': 1,
#   'price': 38,
#   'minimum_nights': 1,
#   'number_of_reviews': 465,
#   'last_review': datetime.datetime(2021, 2, 5, 0, 0),
#   'reviews_per_month': 5.38,
#   'availability_365': 358},
#  {'listing_id': 2230592,
#   'listing_name': 'Loft near Sportpaleis',
#   'host_id': 3488121,
#   'neighbourhood_id': 9,
#   'latitude': 51.22979,
#   'longitude': 4.44464,
#   'room_type_id': 3,
#   'price': 55,
#   'minimum_nights': 1,
#   'number_of_reviews': 37,
#   'last_review': datetime.datetime(2020, 2, 9, 0, 0),
#   'reviews_per_month': 0.43,
#   'availability_365': 90},
#  {'listing_id': 2347414,
#   'listing_name': 'The chill place in Antwerp 2',
#   'host_id': 3189018,
#   'neighbourhood_id': 3,
#   'latitude': 51.21711,
#   'longitude': 4.44417,
#   'room_type_id': 3,
#   'price': 85,
#   'minimum_nights': 2,
#   'number_of_reviews': 1,
#   'last_review': datetime.datetime(2017, 4, 24, 0, 0),
#   'reviews_per_month': 0.02,
#   'availability_365': 178},
#  {'listing_id': 2427717,
#   'listing_name': 'Cosy vintage flat ° center Antwerp',
#   'host_id': 12409903,
#   'neighbourhood_id': 47,
#   'latitude': 51.216590000000004,
#   'longitude': 4.4073,
#   'room_type_id': 1,
#   'price': 110,
#   'minimum_nights': 1,
#   'number_of_reviews': 301,
#   'last_review': datetime.datetime(2020, 7, 26, 0, 0),
#   'reviews_per_month': 3.54,
#   'availability_365': 331},
#  {'listing_id': 2433570,
#   'listing_name': 'charming place on a quiet and green courtyard',
#   'host_id': 12411315,
#   'neighbourhood_id': 45,
#   'latitude': 51.221540000000005,
#   'longitude': 4.4383,
#   'room_type_id': 3,
#   'price': 49,
#   'minimum_nights': 2,
#   'number_of_reviews': 103,
#   'last_review': datetime.datetime(2020, 3, 9, 0, 0),
#   'reviews_per_month': 1.22,
#   'availability_365': 331},
#  {'listing_id': 2436964,
#   'listing_name': 'NEW - Quiet loft in city center w/ private parking',
#   'host_id': 10891625,
#   'neighbourhood_id': 19,
#   'latitude': 51.222570000000005,
#   'longitude': 4.40394,
#   'room_type_id': 1,
#   'price': 105,
#   'minimum_nights': 2,
#   'number_of_reviews': 62,
#   'last_review': datetime.datetime(2020, 7, 12, 0, 0),
#   'reviews_per_month': 2.36,
#   'availability_365': 0},
#  {'listing_id': 2448815,
#   'listing_name': 'MAISON NATIONALE City Flats&Suites',
#   'host_id': 12523959,
#   'neighbourhood_id': 43,
#   'latitude': 51.21699,
#   'longitude': 4.40014,
#   'room_type_id': 3,
#   'price': 165,
#   'minimum_nights': 1,
#   'number_of_reviews': 0,
#   'last_review': datetime.datetime(1990, 1, 1, 0, 0),
#   'reviews_per_month': 0.0,
#   'availability_365': 0},
#  {'listing_id': 2522970,
#   'listing_name': 'Luxury city center apartment  with terrace',
#   'host_id': 12917758,
#   'neighbourhood_id': 47,
#   'latitude': 51.21861,
#   'longitude': 4.4096400000000004,
#   'room_type_id': 1,
#   'price': 114,
#   'minimum_nights': 1,
#   'number_of_reviews': 254,
#   'last_review': datetime.datetime(2020, 12, 30, 0, 0),
#   'reviews_per_month': 3.0,
#   'availability_365': 353},
#  {'listing_id': 2543695,
#   'listing_name': 'aplace/antwerp: gorgeous flat with square view',
#   'host_id': 234077,
#   'neighbourhood_id': 19,
#   'latitude': 51.21825,
#   'longitude': 4.39901,
#   'room_type_id': 1,
#   'price': 176,
#   'minimum_nights': 2,
#   'number_of_reviews': 12,
#   'last_review': datetime.datetime(2018, 12, 7, 0, 0),
#   'reviews_per_month': 0.16,
#   'availability_365': 323},
#  {'listing_id': 2602613,
#   'listing_name': 'Light and spacious duplex apartment',
#   'host_id': 13330269,
#   'neighbourhood_id': 3,
#   'latitude': 51.21611,
#   'longitude': 4.43234,
#   'room_type_id': 1,
#   'price': 65,
#   'minimum_nights': 2,
#   'number_of_reviews': 150,
#   'last_review': datetime.datetime(2021, 2, 7, 0, 0),
#   'reviews_per_month': 1.79,
#   'availability_365': 241},
#  {'listing_id': 2609419,
#   'listing_name': 'Gezellig 1-slpk app. op toplocatie',
#   'host_id': 10342058,
#   'neighbourhood_id': 52,
#   'latitude': 51.20539,
#   'longitude': 4.38821,
#   'room_type_id': 1,
#   'price': 65,
#   'minimum_nights': 1,
#   'number_of_reviews': 29,
#   'last_review': datetime.datetime(2018, 6, 30, 0, 0),
#   'reviews_per_month': 0.38,
#   'availability_365': 287},
#  {'listing_id': 2682808,
#   'listing_name': 'Cosy room in a charming house',
#   'host_id': 13733939,
#   'neighbourhood_id': 39,
#   'latitude': 51.1976,
#   'longitude': 4.42955,
#   'room_type_id': 3,
#   'price': 32,
#   'minimum_nights': 2,
#   'number_of_reviews': 354,
#   'last_review': datetime.datetime(2020, 12, 27, 0, 0),
#   'reviews_per_month': 4.21,
#   'availability_365': 365},
#  {'listing_id': 2762341,
#   'listing_name': 'Comfortable studio downtown Antwerp',
#   'host_id': 5398498,
#   'neighbourhood_id': 1,
#   'latitude': 51.22222,
#   'longitude': 4.41709,
#   'room_type_id': 1,
#   'price': 58,
#   'minimum_nights': 4,
#   'number_of_reviews': 14,
#   'last_review': datetime.datetime(2019, 8, 16, 0, 0),
#   'reviews_per_month': 0.17,
#   'availability_365': 365},
#  {'listing_id': 2819412,
#   'listing_name': "laterrebleue-'my house, your house'",
#   'host_id': 14423888,
#   'neighbourhood_id': 4,
#   'latitude': 51.209140000000005,
#   'longitude': 4.43539,
#   'room_type_id': 4,
#   'price': 37,
#   'minimum_nights': 1,
#   'number_of_reviews': 114,
#   'last_review': datetime.datetime(2021, 1, 11, 0, 0),
#   'reviews_per_month': 1.63,
#   'availability_365': 363},
#  {'listing_id': 3025379,
#   'listing_name': '+++ KAMIL +++ terrace & pond',
#   'host_id': 3185214,
#   'neighbourhood_id': 4,
#   'latitude': 51.21066,
#   'longitude': 4.42863,
#   'room_type_id': 1,
#   'price': 140,
#   'minimum_nights': 2,
#   'number_of_reviews': 174,
#   'last_review': datetime.datetime(2021, 1, 1, 0, 0),
#   'reviews_per_month': 2.15,
#   'availability_365': 256},
#  {'listing_id': 3048594,
#   'listing_name': 'Unique huge loft with private pool and big garden.',
#   'host_id': 6930093,
#   'neighbourhood_id': 3,
#   'latitude': 51.215709999999994,
#   'longitude': 4.43311,
#   'room_type_id': 1,
#   'price': 220,
#   'minimum_nights': 2,
#   'number_of_reviews': 238,
#   'last_review': datetime.datetime(2021, 1, 23, 0, 0),
#   'reviews_per_month': 2.89,
#   'availability_365': 73},
#  {'listing_id': 3197919,
#   'listing_name': '100 years old "master mansion".',
#   'host_id': 16207518,
#   'neighbourhood_id': 18,
#   'latitude': 51.20688,
#   'longitude': 4.40645,
#   'room_type_id': 1,
#   'price': 230,
#   'minimum_nights': 3,
#   'number_of_reviews': 10,
#   'last_review': datetime.datetime(2019, 7, 28, 0, 0),
#   'reviews_per_month': 0.13,
#   'availability_365': 362},
#  {'listing_id': 3202647,
#   'listing_name': 'Penthouse +Terrace @CentralStation',
#   'host_id': 10614479,
#   'neighbourhood_id': 44,
#   'latitude': 51.21757,
#   'longitude': 4.41641,
#   'room_type_id': 1,
#   'price': 72,
#   'minimum_nights': 7,
#   'number_of_reviews': 38,
#   'last_review': datetime.datetime(2020, 12, 6, 0, 0),
#   'reviews_per_month': 0.55,
#   'availability_365': 364},
#  {'listing_id': 3203133,
#   'listing_name': 'Cosy flat in trendy neighbourhood',
#   'host_id': 13572444,
#   'neighbourhood_id': 53,
#   'latitude': 51.206579999999995,
#   'longitude': 4.42614,
#   'room_type_id': 1,
#   'price': 35,
#   'minimum_nights': 20,
#   'number_of_reviews': 11,
#   'last_review': datetime.datetime(2019, 9, 20, 0, 0),
#   'reviews_per_month': 0.14,
#   'availability_365': 56},
#  {'listing_id': 3268690,
#   'listing_name': 'Bright appartment at the South of Antwerp',
#   'host_id': 13665161,
#   'neighbourhood_id': 52,
#   'latitude': 51.20495,
#   'longitude': 4.3897699999999995,
#   'room_type_id': 1,
#   'price': 118,
#   'minimum_nights': 2,
#   'number_of_reviews': 44,
#   'last_review': datetime.datetime(2019, 2, 24, 0, 0),
#   'reviews_per_month': 0.55,
#   'availability_365': 116},
#  {'listing_id': 3518676,
#   'listing_name': 'Charmant appartement op toplocatie!',
#   'host_id': 17717089,
#   'neighbourhood_id': 19,
#   'latitude': 51.22392,
#   'longitude': 4.40238,
#   'room_type_id': 1,
#   'price': 95,
#   'minimum_nights': 2,
#   'number_of_reviews': 77,
#   'last_review': datetime.datetime(2020, 3, 8, 0, 0),
#   'reviews_per_month': 1.0,
#   'availability_365': 357},
#  {'listing_id': 3540493,
#   'listing_name': 'Antwerp City Studio',
#   'host_id': 15709831,
#   'neighbourhood_id': 1,
#   'latitude': 51.21898,
#   'longitude': 4.42506,
#   'room_type_id': 1,
#   'price': 49,
#   'minimum_nights': 2,
#   'number_of_reviews': 279,
#   'last_review': datetime.datetime(2021, 2, 21, 0, 0),
#   'reviews_per_month': 3.47,
#   'availability_365': 343},
#  {'listing_id': 3740347,
#   'listing_name': 'Authentic place city centre',
#   'host_id': 18578941,
#   'neighbourhood_id': 43,
#   'latitude': 51.21334,
#   'longitude': 4.40073,
#   'room_type_id': 1,
#   'price': 110,
#   'minimum_nights': 1,
#   'number_of_reviews': 0,
#   'last_review': datetime.datetime(1990, 1, 1, 0, 0),
#   'reviews_per_month': 0.0,
#   'availability_365': 365},
#  {'listing_id': 3857702,
#   'listing_name': 'Rooms - Apartment - Studio - City Center Antwerp',
#   'host_id': 19891615,
#   'neighbourhood_id': 49,
#   'latitude': 51.2223,
#   'longitude': 4.4074599999999995,
#   'room_type_id': 1,
#   'price': 180,
#   'minimum_nights': 2,
#   'number_of_reviews': 23,
#   'last_review': datetime.datetime(2019, 7, 29, 0, 0),
#   'reviews_per_month': 0.3,
#   'availability_365': 365},
#  {'listing_id': 3894091,
#   'listing_name': 'Cosy and bright apartment for 2',
#   'host_id': 12010306,
#   'neighbourhood_id': 4,
#   'latitude': 51.21154,
#   'longitude': 4.43096,
#   'room_type_id': 1,
#   'price': 65,
#   'minimum_nights': 3,
#   'number_of_reviews': 3,
#   'last_review': datetime.datetime(2015, 10, 20, 0, 0),
#   'reviews_per_month': 0.04,
#   'availability_365': 365},
#  {'listing_id': 3915726,
#   'listing_name': 'Cosy room: Bikes incl.+free parking',
#   'host_id': 14723014,
#   'neighbourhood_id': 38,
#   'latitude': 51.17161,
#   'longitude': 4.42695,
#   'room_type_id': 3,
#   'price': 18,
#   'minimum_nights': 2,
#   'number_of_reviews': 64,
#   'last_review': datetime.datetime(2019, 9, 21, 0, 0),
#   'reviews_per_month': 1.05,
#   'availability_365': 301},
#  {'listing_id': 3969576,
#   'listing_name': 'Privé kamer te huur',
#   'host_id': 20572492,
#   'neighbourhood_id': 4,
#   'latitude': 51.21183,
#   'longitude': 4.44019,
#   'room_type_id': 3,
#   'price': 27,
#   'minimum_nights': 1,
#   'number_of_reviews': 293,
#   'last_review': datetime.datetime(2021, 2, 5, 0, 0),
#   'reviews_per_month': 4.36,
#   'availability_365': 341},
#  {'listing_id': 4017995,
#   'listing_name': 'Studio Daring Indigo',
#   'host_id': 20834666,
#   'neighbourhood_id': 18,
#   'latitude': 51.20767,
#   'longitude': 4.407,
#   'room_type_id': 3,
#   'price': 75,
#   'minimum_nights': 1,
#   'number_of_reviews': 22,
#   'last_review': datetime.datetime(2020, 2, 16, 0, 0),
#   'reviews_per_month': 0.31,
#   'availability_365': 180},
#  {'listing_id': 4026852,
#   'listing_name': 'Luxury townhouse close to the center of Antwerp',
#   'host_id': 20878289,
#   'neighbourhood_id': 20,
#   'latitude': 51.17582,
#   'longitude': 4.3474,
#   'room_type_id': 3,
#   'price': 46,
#   'minimum_nights': 1,
#   'number_of_reviews': 12,
#   'last_review': datetime.datetime(2020, 10, 1, 0, 0),
#   'reviews_per_month': 0.75,
#   'availability_365': 362},
#  {'listing_id': 4030176,
#   'listing_name': 'terrace studio in old Post office Park Spoor Noord',
#   'host_id': 9438737,
#   'neighbourhood_id': 1,
#   'latitude': 51.22677,
#   'longitude': 4.41754,
#   'room_type_id': 1,
#   'price': 50,
#   'minimum_nights': 14,
#   'number_of_reviews': 145,
#   'last_review': datetime.datetime(2020, 11, 27, 0, 0),
#   'reviews_per_month': 1.85,
#   'availability_365': 341},
#  {'listing_id': 4032738,
#   'listing_name': 'Leuk dak appartement, 2 slaapkamers',
#   'host_id': 20906634,
#   'neighbourhood_id': 4,
#   'latitude': 51.21432,
#   'longitude': 4.4362,
#   'room_type_id': 1,
#   'price': 58,
#   'minimum_nights': 2,
#   'number_of_reviews': 17,
#   'last_review': datetime.datetime(2019, 7, 22, 0, 0),
#   'reviews_per_month': 0.22,
#   'availability_365': 41},
#  {'listing_id': 4064854,
#   'listing_name': 'Studio Pancake Paste',
#   'host_id': 20834666,
#   'neighbourhood_id': 18,
#   'latitude': 51.20835,
#   'longitude': 4.4067099999999995,
#   'room_type_id': 3,
#   'price': 75,
#   'minimum_nights': 1,
#   'number_of_reviews': 37,
#   'last_review': datetime.datetime(2019, 11, 29, 0, 0),
#   'reviews_per_month': 0.51,
#   'availability_365': 180},
#  {'listing_id': 4163391,
#   'listing_name': 'Spacious & eclectic loft',
#   'host_id': 7500115,
#   'neighbourhood_id': 14,
#   'latitude': 51.2332,
#   'longitude': 4.4103900000000005,
#   'room_type_id': 1,
#   'price': 196,
#   'minimum_nights': 2,
#   'number_of_reviews': 6,
#   'last_review': datetime.datetime(2018, 10, 20, 0, 0),
#   'reviews_per_month': 0.11,
#   'availability_365': 87},
#  {'listing_id': 4265913,
#   'listing_name': 'Cosy 19th c townhouse near Central Station+parking',
#   'host_id': 22144864,
#   'neighbourhood_id': 45,
#   'latitude': 51.21906,
#   'longitude': 4.430219999999999,
#   'room_type_id': 1,
#   'price': 200,
#   'minimum_nights': 5,
#   'number_of_reviews': 20,
#   'last_review': datetime.datetime(2020, 3, 16, 0, 0),
#   'reviews_per_month': 0.26,
#   'availability_365': 361},
#  {'listing_id': 4303323,
#   'listing_name': 'Den Coninck Achab',
#   'host_id': 22337575,
#   'neighbourhood_id': 49,
#   'latitude': 51.222390000000004,
#   'longitude': 4.41097,
#   'room_type_id': 1,
#   'price': 135,
#   'minimum_nights': 2,
#   'number_of_reviews': 14,
#   'last_review': datetime.datetime(2020, 1, 5, 0, 0),
#   'reviews_per_month': 0.18,
#   'availability_365': 352},
#  {'listing_id': 4322521,
#   'listing_name': 'Duplex 160m² with sauna & piano',
#   'host_id': 15216532,
#   'neighbourhood_id': 52,
#   'latitude': 51.20582,
#   'longitude': 4.38771,
#   'room_type_id': 1,
#   'price': 93,
#   'minimum_nights': 1,
#   'number_of_reviews': 237,
#   'last_review': datetime.datetime(2021, 2, 7, 0, 0),
#   'reviews_per_month': 3.15,
#   'availability_365': 355},
#  {'listing_id': 4332020,
#   'listing_name': "Marleen's cosy first floor flat",
#   'host_id': 1754396,
#   'neighbourhood_id': 30,
#   'latitude': 51.200959999999995,
#   'longitude': 4.40172,
#   'room_type_id': 1,
#   'price': 50,
#   'minimum_nights': 2,
#   'number_of_reviews': 9,
#   'last_review': datetime.datetime(2018, 9, 16, 0, 0),
#   'reviews_per_month': 0.13,
#   'availability_365': 0},
#  {'listing_id': 4425751,
#   'listing_name': 'Bedroom, cosy sitting area & rooftop terrace',
#   'host_id': 3093188,
#   'neighbourhood_id': 44,
#   'latitude': 51.20973,
#   'longitude': 4.41594,
#   'room_type_id': 3,
#   'price': 51,
#   'minimum_nights': 1,
#   'number_of_reviews': 97,
#   'last_review': datetime.datetime(2020, 4, 19, 0, 0),
#   'reviews_per_month': 1.29,
#   'availability_365': 55},
#  {'listing_id': 4444232,
#   'listing_name': 'Charming room in center of Antwerp',
#   'host_id': 23065924,
#   'neighbourhood_id': 19,
#   'latitude': 51.22143,
#   'longitude': 4.402830000000001,
#   'room_type_id': 3,
#   'price': 50,
#   'minimum_nights': 2,
#   'number_of_reviews': 86,
#   'last_review': datetime.datetime(2020, 8, 6, 0, 0),
#   'reviews_per_month': 1.14,
#   'availability_365': 364},
#  {'listing_id': 4502646,
#   'listing_name': 'Unique city loft with amazing view!',
#   'host_id': 13059720,
#   'neighbourhood_id': 43,
#   'latitude': 51.217690000000005,
#   'longitude': 4.3983300000000005,
#   'room_type_id': 1,
#   'price': 79,
#   'minimum_nights': 1,
#   'number_of_reviews': 571,
#   'last_review': datetime.datetime(2021, 2, 19, 0, 0),
#   'reviews_per_month': 7.53,
#   'availability_365': 365},
#  {'listing_id': 4592434,
#   'listing_name': 'Modern 4 pers appartement Antwerpen',
#   'host_id': 23805604,
#   'neighbourhood_id': 14,
#   'latitude': 51.229459999999996,
#   'longitude': 4.40614,
#   'room_type_id': 1,
#   'price': 150,
#   'minimum_nights': 2,
#   'number_of_reviews': 60,
#   'last_review': datetime.datetime(2020, 3, 15, 0, 0),
#   'reviews_per_month': 0.79,
#   'availability_365': 301},
#  {'listing_id': 4703827,
#   'listing_name': 'Spacious loungeroom w/ garden&piano',
#   'host_id': 3015779,
#   'neighbourhood_id': 53,
#   'latitude': 51.20924,
#   'longitude': 4.4251,
#   'room_type_id': 3,
#   'price': 29,
#   'minimum_nights': 1,
#   'number_of_reviews': 16,
#   'last_review': datetime.datetime(2016, 1, 3, 0, 0),
#   'reviews_per_month': 0.21,
#   'availability_365': 271},
#  {'listing_id': 4733497,
#   'listing_name': 'Louise Marie, romantisch huisje',
#   'host_id': 24249803,
#   'neighbourhood_id': 19,
#   'latitude': 51.21785,
#   'longitude': 4.39927,
#   'room_type_id': 1,
#   'price': 190,
#   'minimum_nights': 2,
#   'number_of_reviews': 108,
#   'last_review': datetime.datetime(2020, 7, 19, 0, 0),
#   'reviews_per_month': 1.45,
#   'availability_365': 365},
#  {'listing_id': 4853293,
#   'listing_name': 'Duplex in renovated Coach House',
#   'host_id': 24968524,
#   'neighbourhood_id': 44,
#   'latitude': 51.21034,
#   'longitude': 4.41771,
#   'room_type_id': 3,
#   'price': 115,
#   'minimum_nights': 2,
#   'number_of_reviews': 1,
#   'last_review': datetime.datetime(2015, 6, 22, 0, 0),
#   'reviews_per_month': 0.01,
#   'availability_365': 362},
#  {'listing_id': 4980368,
#   'listing_name': 'Panoramic view restyled appartement',
#   'host_id': 25674863,
#   'neighbourhood_id': 53,
#   'latitude': 51.20579,
#   'longitude': 4.43136,
#   'room_type_id': 1,
#   'price': 79,
#   'minimum_nights': 7,
#   'number_of_reviews': 6,
#   'last_review': datetime.datetime(2018, 4, 20, 0, 0),
#   'reviews_per_month': 0.1,
#   'availability_365': 226},
#  {'listing_id': 4985922,
#   'listing_name': 'Sfeervolle studio in hartje Antwerp',
#   'host_id': 25701603,
#   'neighbourhood_id': 47,
#   'latitude': 51.21011,
#   'longitude': 4.40581,
#   'room_type_id': 1,
#   'price': 75,
#   'minimum_nights': 2,
#   'number_of_reviews': 30,
#   'last_review': datetime.datetime(2020, 1, 2, 0, 0),
#   'reviews_per_month': 0.43,
#   'availability_365': 364},
#  {'listing_id': 5020599,
#   'listing_name': 'Stylish Rooftop next to CHANEL',
#   'host_id': 13357011,
#   'neighbourhood_id': 47,
#   'latitude': 51.21687,
#   'longitude': 4.40709,
#   'room_type_id': 1,
#   'price': 99,
#   'minimum_nights': 7,
#   'number_of_reviews': 44,
#   'last_review': datetime.datetime(2020, 3, 16, 0, 0),
#   'reviews_per_month': 0.6,
#   'availability_365': 308},
#  {'listing_id': 5026455,
#   'listing_name': 'Triplex apt in the heart of Antwerp',
#   'host_id': 4492282,
#   'neighbourhood_id': 19,
#   'latitude': 51.21804,
#   'longitude': 4.3989400000000005,
#   'room_type_id': 1,
#   'price': 171,
#   'minimum_nights': 2,
#   'number_of_reviews': 91,
#   'last_review': datetime.datetime(2020, 3, 16, 0, 0),
#   'reviews_per_month': 1.23,
#   'availability_365': 147},
#  {'listing_id': 5040147,
#   'listing_name': '++HENRI++ furnished apartment with roof terrace',
#   'host_id': 3185214,
#   'neighbourhood_id': 4,
#   'latitude': 51.21161,
#   'longitude': 4.42929,
#   'room_type_id': 1,
#   'price': 93,
#   'minimum_nights': 2,
#   'number_of_reviews': 63,
#   'last_review': datetime.datetime(2020, 12, 7, 0, 0),
#   'reviews_per_month': 0.93,
#   'availability_365': 307},
#  {'listing_id': 5047962,
#   'listing_name': 'Quiet place in an historical quarter',
#   'host_id': 12309348,
#   'neighbourhood_id': 17,
#   'latitude': 51.202690000000004,
#   'longitude': 4.42433,
#   'room_type_id': 3,
#   'price': 60,
#   'minimum_nights': 1,
#   'number_of_reviews': 132,
#   'last_review': datetime.datetime(2020, 9, 23, 0, 0),
#   'reviews_per_month': 1.79,
#   'availability_365': 365},
#  {'listing_id': 5074616,
#   'listing_name': 'Discrete luxury on a top location',
#   'host_id': 26204741,
#   'neighbourhood_id': 14,
#   'latitude': 51.23028,
#   'longitude': 4.41823,
#   'room_type_id': 1,
#   'price': 68,
#   'minimum_nights': 3,
#   'number_of_reviews': 74,
#   'last_review': datetime.datetime(2020, 12, 30, 0, 0),
#   'reviews_per_month': 1.0,
#   'availability_365': 303},
#  {'listing_id': 5096851,
#   'listing_name': 'Double room in cosy and quiet house with garden.',
#   'host_id': 15216025,
#   'neighbourhood_id': 11,
#   'latitude': 51.19984,
#   'longitude': 4.46793,
#   'room_type_id': 3,
#   'price': 75,
#   'minimum_nights': 1,
#   'number_of_reviews': 1,
#   'last_review': datetime.datetime(2018, 5, 21, 0, 0),
#   'reviews_per_month': 0.03,
#   'availability_365': 173},
#  {'listing_id': 5187760,
#   'listing_name': 'A-South Luxury Penthouse Living',
#   'host_id': 24007242,
#   'neighbourhood_id': 52,
#   'latitude': 51.2124,
#   'longitude': 4.39328,
#   'room_type_id': 1,
#   'price': 150,
#   'minimum_nights': 14,
#   'number_of_reviews': 34,
#   'last_review': datetime.datetime(2020, 2, 16, 0, 0),
#   'reviews_per_month': 0.46,
#   'availability_365': 309},
#  {'listing_id': 5223125,
#   'listing_name': 'Modern flat in the historical centrum  of Antwerp',
#   'host_id': 27027069,
#   'neighbourhood_id': 19,
#   'latitude': 51.21835,
#   'longitude': 4.400180000000001,
#   'room_type_id': 1,
#   'price': 48,
#   'minimum_nights': 1,
#   'number_of_reviews': 339,
#   'last_review': datetime.datetime(2020, 3, 15, 0, 0),
#   'reviews_per_month': 4.6,
#   'availability_365': 362},
#  {'listing_id': 5233718,
#   'listing_name': 'Apartment in Antwerp',
#   'host_id': 27086764,
#   'neighbourhood_id': 47,
#   'latitude': 51.21655,
#   'longitude': 4.41352,
#   'room_type_id': 1,
#   'price': 56,
#   'minimum_nights': 2,
#   'number_of_reviews': 21,
#   'last_review': datetime.datetime(2020, 10, 11, 0, 0),
#   'reviews_per_month': 0.29,
#   'availability_365': 192},
#  {'listing_id': 5379855,
#   'listing_name': 'Classy and spacious 19th cent loft with terrace.',
#   'host_id': 11534275,
#   'neighbourhood_id': 4,
#   'latitude': 51.21464,
#   'longitude': 4.43446,
#   'room_type_id': 1,
#   'price': 149,
#   'minimum_nights': 2,
#   'number_of_reviews': 179,
#   'last_review': datetime.datetime(2021, 2, 6, 0, 0),
#   'reviews_per_month': 2.49,
#   'availability_365': 79},
#  {'listing_id': 5417459,
#   'listing_name': 'Full house with garden, near by tram',
#   'host_id': 7553126,
#   'neighbourhood_id': 20,
#   'latitude': 51.17887,
#   'longitude': 4.36301,
#   'room_type_id': 1,
#   'price': 50,
#   'minimum_nights': 2,
#   'number_of_reviews': 91,
#   'last_review': datetime.datetime(2020, 6, 21, 0, 0),
#   'reviews_per_month': 1.5,
#   'availability_365': 26},
#  {'listing_id': 5574536,
#   'listing_name': 'Central studio in historic center',
#   'host_id': 28902892,
#   'neighbourhood_id': 19,
#   'latitude': 51.22019,
#   'longitude': 4.4,
#   'room_type_id': 1,
#   'price': 85,
#   'minimum_nights': 2,
#   'number_of_reviews': 100,
#   'last_review': datetime.datetime(2020, 8, 4, 0, 0),
#   'reviews_per_month': 1.4,
#   'availability_365': 359},
#  {'listing_id': 5575185,
#   'listing_name': 'Central apartment w/ exclusive view',
#   'host_id': 28902892,
#   'neighbourhood_id': 19,
#   'latitude': 51.21873,
#   'longitude': 4.39963,
#   'room_type_id': 1,
#   'price': 115,
#   'minimum_nights': 2,
#   'number_of_reviews': 215,
#   'last_review': datetime.datetime(2020, 10, 7, 0, 0),
#   'reviews_per_month': 2.98,
#   'availability_365': 278},
#  {'listing_id': 5578067,
#   'listing_name': 'Design loft in historic building',
#   'host_id': 28920566,
#   'neighbourhood_id': 49,
#   'latitude': 51.220909999999996,
#   'longitude': 4.4164,
#   'room_type_id': 4,
#   'price': 85,
#   'minimum_nights': 1,
#   'number_of_reviews': 174,
#   'last_review': datetime.datetime(2020, 3, 15, 0, 0),
#   'reviews_per_month': 2.42,
#   'availability_365': 142},
#  {'listing_id': 5646286,
#   'listing_name': 'NESTT',
#   'host_id': 4715596,
#   'neighbourhood_id': 3,
#   'latitude': 51.21464,
#   'longitude': 4.43711,
#   'room_type_id': 1,
#   'price': 55,
#   'minimum_nights': 2,
#   'number_of_reviews': 50,
#   'last_review': datetime.datetime(2021, 2, 21, 0, 0),
#   'reviews_per_month': 0.7,
#   'availability_365': 151},
#  {'listing_id': 5702020,
#   'listing_name': 'Where living becomes poetry...',
#   'host_id': 29563257,
#   'neighbourhood_id': 43,
#   'latitude': 51.214909999999996,
#   'longitude': 4.39732,
#   'room_type_id': 1,
#   'price': 90,
#   'minimum_nights': 2,
#   'number_of_reviews': 86,
#   'last_review': datetime.datetime(2021, 1, 31, 0, 0),
#   'reviews_per_month': 1.19,
#   'availability_365': 171},
#  {'listing_id': 5741728,
#   'listing_name': '"la casa di Frà"',
#   'host_id': 29779875,
#   'neighbourhood_id': 4,
#   'latitude': 51.21484,
#   'longitude': 4.431690000000001,
#   'room_type_id': 1,
#   'price': 70,
#   'minimum_nights': 1,
#   'number_of_reviews': 34,
#   'last_review': datetime.datetime(2018, 3, 4, 0, 0),
#   'reviews_per_month': 0.48,
#   'availability_365': 0},
#  {'listing_id': 5789730,
#   'listing_name': 'Back to Beck',
#   'host_id': 30038566,
#   'neighbourhood_id': 11,
#   'latitude': 51.19612,
#   'longitude': 4.46167,
#   'room_type_id': 1,
#   'price': 79,
#   'minimum_nights': 1,
#   'number_of_reviews': 41,
#   'last_review': datetime.datetime(2020, 9, 13, 0, 0),
#   'reviews_per_month': 0.57,
#   'availability_365': 301},
#  {'listing_id': 5922786,
#   'listing_name': 'Smartflats Meir 301 - 2 Bedrooms - Meir Area',
#   'host_id': 2792958,
#   'neighbourhood_id': 47,
#   'latitude': 51.21902,
#   'longitude': 4.40909,
#   'room_type_id': 1,
#   'price': 153,
#   'minimum_nights': 1,
#   'number_of_reviews': 51,
#   'last_review': datetime.datetime(2021, 2, 7, 0, 0),
#   'reviews_per_month': 0.76,
#   'availability_365': 338},
#  {'listing_id': 5923210,
#   'listing_name': 'Smartflats Meir 401 - 2 Bedrooms - Meir Area',
#   'host_id': 2792958,
#   'neighbourhood_id': 47,
#   'latitude': 51.21857,
#   'longitude': 4.408980000000001,
#   'room_type_id': 1,
#   'price': 153,
#   'minimum_nights': 1,
#   'number_of_reviews': 24,
#   'last_review': datetime.datetime(2020, 9, 14, 0, 0),
#   'reviews_per_month': 0.36,
#   'availability_365': 289},
#  {'listing_id': 5923754,
#   'listing_name': 'Smartflats Meir 501 - 1 Bedroom - Meir Area',
#   'host_id': 2792958,
#   'neighbourhood_id': 47,
#   'latitude': 51.21837,
#   'longitude': 4.40868,
#   'room_type_id': 1,
#   'price': 138,
#   'minimum_nights': 1,
#   'number_of_reviews': 14,
#   'last_review': datetime.datetime(2021, 1, 28, 0, 0),
#   'reviews_per_month': 0.21,
#   'availability_365': 351},
#  {'listing_id': 5940310,
#   'listing_name': 'Adorable happy positive vibes place',
#   'host_id': 4586965,
#   'neighbourhood_id': 24,
#   'latitude': 51.182359999999996,
#   'longitude': 4.3893699999999995,
#   'room_type_id': 1,
#   'price': 110,
#   'minimum_nights': 1,
#   'number_of_reviews': 52,
#   'last_review': datetime.datetime(2020, 7, 25, 0, 0),
#   'reviews_per_month': 0.91,
#   'availability_365': 363},
#  {'listing_id': 5994895,
#   'listing_name': 'Cosy apartment in historic house',
#   'host_id': 11857224,
#   'neighbourhood_id': 19,
#   'latitude': 51.22076,
#   'longitude': 4.39855,
#   'room_type_id': 1,
#   'price': 118,
#   'minimum_nights': 3,
#   'number_of_reviews': 25,
#   'last_review': datetime.datetime(2020, 3, 9, 0, 0),
#   'reviews_per_month': 0.36,
#   'availability_365': 365},
#  {'listing_id': 6000928,
#   'listing_name': 'Arendshof',
#   'host_id': 29134589,
#   'neighbourhood_id': 10,
#   'latitude': 51.22319,
#   'longitude': 4.48347,
#   'room_type_id': 1,
#   'price': 135,
#   'minimum_nights': 1,
#   'number_of_reviews': 15,
#   'last_review': datetime.datetime(2019, 11, 29, 0, 0),
#   'reviews_per_month': 0.24,
#   'availability_365': 363},
#  {'listing_id': 6004053,
#   'listing_name': "Room at 20 min.' walk from center",
#   'host_id': 31168861,
#   'neighbourhood_id': 5,
#   'latitude': 51.203990000000005,
#   'longitude': 4.39827,
#   'room_type_id': 3,
#   'price': 20,
#   'minimum_nights': 10,
#   'number_of_reviews': 27,
#   'last_review': datetime.datetime(2018, 9, 10, 0, 0),
#   'reviews_per_month': 0.38,
#   'availability_365': 241},
#  {'listing_id': 6046872,
#   'listing_name': 'Feel Good  Antwerp City Apartment',
#   'host_id': 27432928,
#   'neighbourhood_id': 18,
#   'latitude': 51.2061,
#   'longitude': 4.40915,
#   'room_type_id': 1,
#   'price': 74,
#   'minimum_nights': 3,
#   'number_of_reviews': 56,
#   'last_review': datetime.datetime(2020, 11, 30, 0, 0),
#   'reviews_per_month': 2.32,
#   'availability_365': 85},
#  {'listing_id': 6051973,
#   'listing_name': "Welcome @Tempor'area, reopening June 8th! :-)",
#   'host_id': 3970988,
#   'neighbourhood_id': 47,
#   'latitude': 51.213359999999994,
#   'longitude': 4.40415,
#   'room_type_id': 1,
#   'price': 134,
#   'minimum_nights': 2,
#   'number_of_reviews': 67,
#   'last_review': datetime.datetime(2020, 10, 15, 0, 0),
#   'reviews_per_month': 0.94,
#   'availability_365': 263},
#  {'listing_id': 6071213,
#   'listing_name': "At Granny's near Rivierenhof",
#   'host_id': 1820186,
#   'neighbourhood_id': 10,
#   'latitude': 51.22075,
#   'longitude': 4.4785699999999995,
#   'room_type_id': 3,
#   'price': 17,
#   'minimum_nights': 14,
#   'number_of_reviews': 9,
#   'last_review': datetime.datetime(2020, 7, 19, 0, 0),
#   'reviews_per_month': 0.13,
#   'availability_365': 294},
#  {'listing_id': 6149034,
#   'listing_name': 'Lovely flat with spectacular view!',
#   'host_id': 25673165,
#   'neighbourhood_id': 14,
#   'latitude': 51.23273,
#   'longitude': 4.40394,
#   'room_type_id': 1,
#   'price': 31,
#   'minimum_nights': 2,
#   'number_of_reviews': 284,
#   'last_review': datetime.datetime(2021, 1, 16, 0, 0),
#   'reviews_per_month': 4.01,
#   'availability_365': 350},
#  {'listing_id': 6183201,
#   'listing_name': 'Duplex Studio',
#   'host_id': 31447903,
#   'neighbourhood_id': 52,
#   'latitude': 51.20649,
#   'longitude': 4.3928400000000005,
#   'room_type_id': 1,
#   'price': 75,
#   'minimum_nights': 2,
#   'number_of_reviews': 50,
#   'last_review': datetime.datetime(2019, 9, 10, 0, 0),
#   'reviews_per_month': 0.7,
# ...
#   'neighbourhood_id': 47,
#   'latitude': 51.21888,
#   'longitude': 4.407369999999999,
#   'room_type_id': 1,
#   'price': 51,
#   'minimum_nights': 1,
#   'number_of_reviews': 32,
#   'last_review': datetime.datetime(2021, 1, 31, 0, 0),
#   'reviews_per_month': 1.61,
#   'availability_365': 349},
#  {'listing_id': 35994544,
#   'listing_name': 'Room',
#   'host_id': 101160374,
#   'neighbourhood_id': 1,
#   'latitude': 51.22568,
#   'longitude': 4.41971,
#   'room_type_id': 3,
#   'price': 25,
#   'minimum_nights': 25,
#   'number_of_reviews': 0,
#   'last_review': datetime.datetime(1990, 1, 1, 0, 0),
#   'reviews_per_month': 0.0,
#   'availability_365': 363},
#  {'listing_id': 35996665,
#   'listing_name': 'Meir Lodge. Apartment in Centre of Antwerp 2R',
#   'host_id': 165436938,
#   'neighbourhood_id': 47,
#   'latitude': 51.21949,
#   'longitude': 4.40725,
#   'room_type_id': 1,
#   'price': 51,
#   'minimum_nights': 1,
#   'number_of_reviews': 30,
#   'last_review': datetime.datetime(2020, 8, 28, 0, 0),
#   'reviews_per_month': 1.49,
#   'availability_365': 311},
#  {'listing_id': 35997401,
#   'listing_name': 'Meir Lodge. Apartment Central Antwerp 3L',
#   'host_id': 165436938,
#   'neighbourhood_id': 47,
#   'latitude': 51.219570000000004,
#   'longitude': 4.40716,
#   'room_type_id': 1,
#   'price': 51,
#   'minimum_nights': 1,
#   'number_of_reviews': 25,
#   'last_review': datetime.datetime(2020, 9, 4, 0, 0),
#   'reviews_per_month': 1.27,
#   'availability_365': 329},
#  {'listing_id': 36000589,
#   'listing_name': 'Superior Light House Apartment Centre of Antwerp |',
#   'host_id': 165436938,
#   'neighbourhood_id': 19,
#   'latitude': 51.22291,
#   'longitude': 4.40311,
#   'room_type_id': 1,
#   'price': 51,
#   'minimum_nights': 1,
#   'number_of_reviews': 51,
#   'last_review': datetime.datetime(2021, 2, 7, 0, 0),
#   'reviews_per_month': 2.61,
#   'availability_365': 319},
#  {'listing_id': 36016441,
#   'listing_name': 'The Red Monkey',
#   'host_id': 270964935,
#   'neighbourhood_id': 43,
#   'latitude': 51.21419,
#   'longitude': 4.40013,
#   'room_type_id': 1,
#   'price': 91,
#   'minimum_nights': 1,
#   'number_of_reviews': 11,
#   'last_review': datetime.datetime(2020, 7, 4, 0, 0),
#   'reviews_per_month': 0.59,
#   'availability_365': 331},
#  {'listing_id': 36020300,
#   'listing_name': 'The Blue Parrot',
#   'host_id': 270964935,
#   'neighbourhood_id': 43,
#   'latitude': 51.21419,
#   'longitude': 4.40013,
#   'room_type_id': 1,
#   'price': 68,
#   'minimum_nights': 1,
#   'number_of_reviews': 10,
#   'last_review': datetime.datetime(2020, 11, 8, 0, 0),
#   'reviews_per_month': 0.5,
#   'availability_365': 274},
#  {'listing_id': 36029902,
#   'listing_name': 'The Light Blue Parrot',
#   'host_id': 270964935,
#   'neighbourhood_id': 43,
#   'latitude': 51.21419,
#   'longitude': 4.40013,
#   'room_type_id': 1,
#   'price': 65,
#   'minimum_nights': 1,
#   'number_of_reviews': 26,
#   'last_review': datetime.datetime(2021, 2, 21, 0, 0),
#   'reviews_per_month': 1.29,
#   'availability_365': 360},
#  {'listing_id': 36031281,
#   'listing_name': 'The Pink Pigeon',
#   'host_id': 270964935,
#   'neighbourhood_id': 43,
#   'latitude': 51.21419,
#   'longitude': 4.40013,
#   'room_type_id': 1,
#   'price': 121,
#   'minimum_nights': 1,
#   'number_of_reviews': 25,
#   'last_review': datetime.datetime(2020, 3, 9, 0, 0),
#   'reviews_per_month': 1.24,
#   'availability_365': 269},
#  {'listing_id': 36060782,
#   'listing_name': 'Sunny cityflat Dageraad/Zurenborg bn 2 stations',
#   'host_id': 222228669,
#   'neighbourhood_id': 53,
#   'latitude': 51.20648,
#   'longitude': 4.42623,
#   'room_type_id': 1,
#   'price': 60,
#   'minimum_nights': 5,
#   'number_of_reviews': 10,
#   'last_review': datetime.datetime(2020, 1, 3, 0, 0),
#   'reviews_per_month': 0.51,
#   'availability_365': 37},
#  {'listing_id': 36068325,
#   'listing_name': 'Spacious bright appartement with harbour view.',
#   'host_id': 148956742,
#   'neighbourhood_id': 14,
#   'latitude': 51.23445,
#   'longitude': 4.41418,
#   'room_type_id': 1,
#   'price': 75,
#   'minimum_nights': 14,
#   'number_of_reviews': 20,
#   'last_review': datetime.datetime(2020, 3, 15, 0, 0),
#   'reviews_per_month': 1.02,
#   'availability_365': 86},
#  {'listing_id': 36078330,
#   'listing_name': 'Peacefull room with window in the centre Antwerpen',
#   'host_id': 271323164,
#   'neighbourhood_id': 12,
#   'latitude': 51.2106,
#   'longitude': 4.45444,
#   'room_type_id': 3,
#   'price': 30,
#   'minimum_nights': 1,
#   'number_of_reviews': 4,
#   'last_review': datetime.datetime(2020, 1, 2, 0, 0),
#   'reviews_per_month': 0.22,
#   'availability_365': 364},
#  {'listing_id': 36086423,
#   'listing_name': 'Cozy apartment in the trendy area "Het Eilandje"',
#   'host_id': 264997545,
#   'neighbourhood_id': 19,
#   'latitude': 51.21828,
#   'longitude': 4.40348,
#   'room_type_id': 1,
#   'price': 139,
#   'minimum_nights': 1,
#   'number_of_reviews': 1,
#   'last_review': datetime.datetime(2019, 10, 27, 0, 0),
#   'reviews_per_month': 0.06,
#   'availability_365': 89},
#  {'listing_id': 36098300,
#   'listing_name': 'The Red With Pearls',
#   'host_id': 270964935,
#   'neighbourhood_id': 47,
#   'latitude': 51.214620000000004,
#   'longitude': 4.40324,
#   'room_type_id': 1,
#   'price': 88,
#   'minimum_nights': 1,
#   'number_of_reviews': 19,
#   'last_review': datetime.datetime(2021, 2, 14, 0, 0),
#   'reviews_per_month': 0.95,
#   'availability_365': 360},
#  {'listing_id': 36099404,
#   'listing_name': 'Penth-house Apartment in the Centre of Antwerp',
#   'host_id': 165436938,
#   'neighbourhood_id': 49,
#   'latitude': 51.2205,
#   'longitude': 4.41043,
#   'room_type_id': 1,
#   'price': 51,
#   'minimum_nights': 1,
#   'number_of_reviews': 56,
#   'last_review': datetime.datetime(2021, 2, 9, 0, 0),
#   'reviews_per_month': 2.82,
#   'availability_365': 331},
#  {'listing_id': 36099494,
#   'listing_name': 'The Black Pants',
#   'host_id': 270964935,
#   'neighbourhood_id': 47,
#   'latitude': 51.214620000000004,
#   'longitude': 4.40324,
#   'room_type_id': 1,
#   'price': 103,
#   'minimum_nights': 1,
#   'number_of_reviews': 9,
#   'last_review': datetime.datetime(2020, 3, 9, 0, 0),
#   'reviews_per_month': 0.46,
#   'availability_365': 350},
#  {'listing_id': 36102951,
#   'listing_name': 'Lily Apartment. Discover the Heart of Antwerp',
#   'host_id': 165436938,
#   'neighbourhood_id': 47,
#   'latitude': 51.21937,
#   'longitude': 4.410909999999999,
#   'room_type_id': 1,
#   'price': 51,
#   'minimum_nights': 1,
#   'number_of_reviews': 19,
#   'last_review': datetime.datetime(2021, 1, 10, 0, 0),
#   'reviews_per_month': 1.01,
#   'availability_365': 331},
#  {'listing_id': 36106533,
#   'listing_name': '130m²  house near station & sportpaleis + parking',
#   'host_id': 271595247,
#   'neighbourhood_id': 3,
#   'latitude': 51.22148,
#   'longitude': 4.44086,
#   'room_type_id': 1,
#   'price': 100,
#   'minimum_nights': 1,
#   'number_of_reviews': 44,
#   'last_review': datetime.datetime(2021, 2, 21, 0, 0),
#   'reviews_per_month': 2.25,
#   'availability_365': 346},
#  {'listing_id': 36111111,
#   'listing_name': 'Sunny central studio with amazing city views',
#   'host_id': 10661360,
#   'neighbourhood_id': 19,
#   'latitude': 51.22144,
#   'longitude': 4.3993,
#   'room_type_id': 1,
#   'price': 100,
#   'minimum_nights': 28,
#   'number_of_reviews': 1,
#   'last_review': datetime.datetime(2020, 2, 9, 0, 0),
#   'reviews_per_month': 0.08,
#   'availability_365': 0},
#  {'listing_id': 36195542,
#   'listing_name': 'City trip Antwerp and staying in your own bubble.',
#   'host_id': 229286450,
#   'neighbourhood_id': 32,
#   'latitude': 51.189009999999996,
#   'longitude': 4.3958900000000005,
#   'room_type_id': 1,
#   'price': 40,
#   'minimum_nights': 1,
#   'number_of_reviews': 15,
#   'last_review': datetime.datetime(2021, 2, 22, 0, 0),
#   'reviews_per_month': 0.78,
#   'availability_365': 312},
#  {'listing_id': 36220043,
#   'listing_name': 'Fabulous studio at 100 meter from central station',
#   'host_id': 208300147,
#   'neighbourhood_id': 1,
#   'latitude': 51.22184,
#   'longitude': 4.42093,
#   'room_type_id': 1,
#   'price': 55,
#   'minimum_nights': 2,
#   'number_of_reviews': 120,
#   'last_review': datetime.datetime(2021, 2, 23, 0, 0),
#   'reviews_per_month': 5.98,
#   'availability_365': 337},
#  {'listing_id': 36253626,
#   'listing_name': '3 bedroom apartment in the centre of Antwerp',
#   'host_id': 264440567,
#   'neighbourhood_id': 24,
#   'latitude': 51.18817,
#   'longitude': 4.37487,
#   'room_type_id': 1,
#   'price': 120,
#   'minimum_nights': 14,
#   'number_of_reviews': 0,
#   'last_review': datetime.datetime(1990, 1, 1, 0, 0),
#   'reviews_per_month': 0.0,
#   'availability_365': 364},
#  {'listing_id': 36278065,
#   'listing_name': 'Beautiful house: 2 bedrooms\nEverywhere fast by car',
#   'host_id': 232962937,
#   'neighbourhood_id': 51,
#   'latitude': 51.16435,
#   'longitude': 4.38685,
#   'room_type_id': 3,
#   'price': 100,
#   'minimum_nights': 1,
#   'number_of_reviews': 2,
#   'last_review': datetime.datetime(2019, 9, 22, 0, 0),
#   'reviews_per_month': 0.11,
#   'availability_365': 0},
#  {'listing_id': 36303786,
#   'listing_name': 'The Suit',
#   'host_id': 270964935,
#   'neighbourhood_id': 47,
#   'latitude': 51.214620000000004,
#   'longitude': 4.40324,
#   'room_type_id': 1,
#   'price': 94,
#   'minimum_nights': 1,
#   'number_of_reviews': 10,
#   'last_review': datetime.datetime(2020, 2, 12, 0, 0),
#   'reviews_per_month': 0.54,
#   'availability_365': 358},
#  {'listing_id': 36309287,
#   'listing_name': 'Studio: City Center, Botanical Garden, Parking',
#   'host_id': 273021773,
#   'neighbourhood_id': 47,
#   'latitude': 51.21328,
#   'longitude': 4.40813,
#   'room_type_id': 1,
#   'price': 47,
#   'minimum_nights': 2,
#   'number_of_reviews': 25,
#   'last_review': datetime.datetime(2020, 7, 27, 0, 0),
#   'reviews_per_month': 1.26,
#   'availability_365': 177},
#  {'listing_id': 36350823,
#   'listing_name': 'Modern Industrial Designed appartment',
#   'host_id': 46690724,
#   'neighbourhood_id': 1,
#   'latitude': 51.220909999999996,
#   'longitude': 4.4204300000000005,
#   'room_type_id': 1,
#   'price': 79,
#   'minimum_nights': 2,
#   'number_of_reviews': 5,
#   'last_review': datetime.datetime(2020, 3, 16, 0, 0),
#   'reviews_per_month': 0.29,
#   'availability_365': 364},
#  {'listing_id': 36355231,
#   'listing_name': 'Comfortble apart Antwerp Cntral is 5 mins bus-tram',
#   'host_id': 273393688,
#   'neighbourhood_id': 3,
#   'latitude': 51.21754,
#   'longitude': 4.437819999999999,
#   'room_type_id': 3,
#   'price': 25,
#   'minimum_nights': 1,
#   'number_of_reviews': 0,
#   'last_review': datetime.datetime(1990, 1, 1, 0, 0),
#   'reviews_per_month': 0.0,
#   'availability_365': 173},
#  {'listing_id': 36385093,
#   'listing_name': 'The 16th century Horse Alley',
#   'host_id': 3944687,
#   'neighbourhood_id': 43,
#   'latitude': 51.2124,
#   'longitude': 4.39515,
#   'room_type_id': 1,
#   'price': 75,
#   'minimum_nights': 2,
#   'number_of_reviews': 11,
#   'last_review': datetime.datetime(2019, 12, 30, 0, 0),
#   'reviews_per_month': 0.57,
#   'availability_365': 42},
#  {'listing_id': 36422080,
#   'listing_name': 'Art Deco Suite',
#   'host_id': 15780894,
#   'neighbourhood_id': 49,
#   'latitude': 51.221709999999995,
#   'longitude': 4.40644,
#   'room_type_id': 3,
#   'price': 42,
#   'minimum_nights': 1,
#   'number_of_reviews': 105,
#   'last_review': datetime.datetime(2021, 2, 10, 0, 0),
#   'reviews_per_month': 5.41,
#   'availability_365': 2},
#  {'listing_id': 36433061,
#   'listing_name': 'Cosy room in cohousing house 3th floor',
#   'host_id': 189196082,
#   'neighbourhood_id': 1,
#   'latitude': 51.21822,
#   'longitude': 4.43042,
#   'room_type_id': 3,
#   'price': 35,
#   'minimum_nights': 2,
#   'number_of_reviews': 11,
#   'last_review': datetime.datetime(2020, 2, 10, 0, 0),
#   'reviews_per_month': 0.56,
#   'availability_365': 8},
#  {'listing_id': 36444570,
#   'listing_name': ',.. Bright room in historic house (city_ centre)',
#   'host_id': 7034290,
#   'neighbourhood_id': 19,
#   'latitude': 51.22352,
#   'longitude': 4.40371,
#   'room_type_id': 3,
#   'price': 22,
#   'minimum_nights': 2,
#   'number_of_reviews': 6,
#   'last_review': datetime.datetime(2019, 8, 5, 0, 0),
#   'reviews_per_month': 0.3,
#   'availability_365': 92},
#  {'listing_id': 36463785,
#   'listing_name': 'Spacious light room in the heart of Antwerp',
#   'host_id': 274159140,
#   'neighbourhood_id': 6,
#   'latitude': 51.21309,
#   'longitude': 4.4168,
#   'room_type_id': 3,
#   'price': 60,
#   'minimum_nights': 1,
#   'number_of_reviews': 8,
#   'last_review': datetime.datetime(2021, 2, 14, 0, 0),
#   'reviews_per_month': 0.41,
#   'availability_365': 116},
#  {'listing_id': 36464525,
#   'listing_name': 'Spacious room in the heart of Antwerp',
#   'host_id': 274159140,
#   'neighbourhood_id': 6,
#   'latitude': 51.21293,
#   'longitude': 4.41909,
#   'room_type_id': 3,
#   'price': 65,
#   'minimum_nights': 1,
#   'number_of_reviews': 34,
#   'last_review': datetime.datetime(2020, 7, 17, 0, 0),
#   'reviews_per_month': 1.74,
#   'availability_365': 301},
#  {'listing_id': 36469302,
#   'listing_name': 'Bright and Green fully equiped Garden apartment',
#   'host_id': 41812074,
#   'neighbourhood_id': 45,
#   'latitude': 51.21841,
#   'longitude': 4.43081,
#   'room_type_id': 1,
#   'price': 68,
#   'minimum_nights': 1,
#   'number_of_reviews': 23,
#   'last_review': datetime.datetime(2020, 9, 12, 0, 0),
#   'reviews_per_month': 1.17,
#   'availability_365': 86},
#  {'listing_id': 36494577,
#   'listing_name': 'New: full appartement classy strategic location',
#   'host_id': 157525654,
#   'neighbourhood_id': 44,
#   'latitude': 51.206140000000005,
#   'longitude': 4.41136,
#   'room_type_id': 1,
#   'price': 62,
#   'minimum_nights': 3,
#   'number_of_reviews': 32,
#   'last_review': datetime.datetime(2021, 1, 16, 0, 0),
#   'reviews_per_month': 1.78,
#   'availability_365': 317},
#  {'listing_id': 36499599,
#   'listing_name': 'Luxury big apartment in city center of Antwerp!',
#   'host_id': 274427263,
#   'neighbourhood_id': 47,
#   'latitude': 51.21683,
#   'longitude': 4.40421,
#   'room_type_id': 1,
#   'price': 125,
#   'minimum_nights': 2,
#   'number_of_reviews': 1,
#   'last_review': datetime.datetime(2019, 9, 10, 0, 0),
#   'reviews_per_month': 0.06,
#   'availability_365': 177},
#  {'listing_id': 36503455,
#   'listing_name': 'Roomy and light city house 15 min from city centre',
#   'host_id': 14494301,
#   'neighbourhood_id': 9,
#   'latitude': 51.23411,
#   'longitude': 4.44565,
#   'room_type_id': 1,
#   'price': 80,
#   'minimum_nights': 1,
#   'number_of_reviews': 29,
#   'last_review': datetime.datetime(2021, 2, 8, 0, 0),
#   'reviews_per_month': 1.54,
#   'availability_365': 350},
#  {'listing_id': 36520988,
#   'listing_name': 'Trendy & Spacious appartement',
#   'host_id': 4664027,
#   'neighbourhood_id': 30,
#   'latitude': 51.202040000000004,
#   'longitude': 4.40466,
#   'room_type_id': 1,
#   'price': 32,
#   'minimum_nights': 4,
#   'number_of_reviews': 1,
#   'last_review': datetime.datetime(2019, 8, 20, 0, 0),
#   'reviews_per_month': 0.05,
#   'availability_365': 0},
#  {'listing_id': 36612160,
#   'listing_name': 'Long term rent appartment',
#   'host_id': 16824272,
#   'neighbourhood_id': 16,
#   'latitude': 51.20218,
#   'longitude': 4.44297,
#   'room_type_id': 1,
#   'price': 40,
#   'minimum_nights': 90,
#   'number_of_reviews': 0,
#   'last_review': datetime.datetime(1990, 1, 1, 0, 0),
#   'reviews_per_month': 0.0,
#   'availability_365': 0},
#  {'listing_id': 36660088,
#   'listing_name': 'Cozy bright apartment in the heart of Antwerp',
#   'host_id': 27046365,
#   'neighbourhood_id': 19,
#   'latitude': 51.22156,
#   'longitude': 4.39795,
#   'room_type_id': 3,
#   'price': 55,
#   'minimum_nights': 2,
#   'number_of_reviews': 3,
#   'last_review': datetime.datetime(2020, 3, 8, 0, 0),
#   'reviews_per_month': 0.18,
#   'availability_365': 88},
#  {'listing_id': 36667763,
#   'listing_name': 'The Card Room Green Studio',
#   'host_id': 270964935,
#   'neighbourhood_id': 47,
#   'latitude': 51.21346,
#   'longitude': 4.40891,
#   'room_type_id': 1,
#   'price': 51,
#   'minimum_nights': 1,
#   'number_of_reviews': 24,
#   'last_review': datetime.datetime(2021, 2, 21, 0, 0),
#   'reviews_per_month': 1.23,
#   'availability_365': 357},
#  {'listing_id': 36671122,
#   'listing_name': 'Quiet mini studio in row house near Sportpaleis',
#   'host_id': 96769191,
#   'neighbourhood_id': 9,
#   'latitude': 51.22574,
#   'longitude': 4.453180000000001,
#   'room_type_id': 3,
#   'price': 37,
#   'minimum_nights': 1,
#   'number_of_reviews': 20,
#   'last_review': datetime.datetime(2020, 3, 8, 0, 0),
#   'reviews_per_month': 1.02,
#   'availability_365': 360},
#  ...]

# %%
ins = listings.insert()

# %%
result=connection.execute(ins, lst)

# %% [markdown]
# Проверка с помощью запроса

# %%
sel = select([listings])
rp = connection.execute(sel).fetchone()
pprint(rp)
# Out:
# (50904, 'aplace/antwerp: cosy suite - fashion district', 234077, 19, Decimal('51.22'), Decimal('4.40'), 2, 145, 1, 1, datetime.datetime(2015, 5, 6, 0, 0), Decimal('0.01'), b'\xe2\x00\x00\x00\x00\x00\x00\x00')

# %%
l=df.loc[0,'latitude']
print(l, type(l), type(float(l)))
# Out:
# 51.21825 <class 'numpy.float64'> <class 'float'>

# %% [markdown]
# ## 4.2 Таблицы *users, orders, line_items*

# %%
def insert_values(table, values_list):
    for value in values_list:
        ins = insert(table).values(value)
        connection.execute(ins)

# %%
user_list=[(1,'Nicolas','nicolas@rambler.ru','+7-929-616-88-77','@#$%890'),
           (2,'Lida','lidaok@gmail.com','+7-929-616-88-77','yyT$%333'),
           (3,'Vera','lveramuns@gmail.com','+7-353-214-12-90','yyT$%333'),
           (4,'Ivan','ivaturgenev@yandex.ru','+7-047-121-89-95','tT6^7&#20Oy'),
           (5,'Svetlana','svetaivanova@microsoft.com','+7-812-555-48-71','SD%@OUsdc7')
          ]
insert_values(user,user_list)

# %%
sel=select([user])
connection.execute(sel).fetchone()

# %%
order_list=[(1,1,True,500),
            (2,2,True,150),
            (3,3,True,180),
            (4,1,True,200),
            (5,2,True,220)]
insert_values(order,order_list)

# %%
sel=select([order])
connection.execute(sel).fetchone()

# %%
sel=select([listings.c.price])
connection.execute(sel).fetchone()

# %%
sel = select([func.max(listings.c.price)])
connection.execute(sel).scalar()
